# %%
module('load', 'pytorch/gpu-cuda-12.1/2.2.0')

# %%
from catalog_manager import CatalogManager
from shared_utils import _grid_lens, _plot2D_on_grid


# #lens_grid=_grid_lens(3.0, 1000, device="cpu")
# my_catalog = CatalogManager(catalog_name="conor_train_gauss_source_10e6_6_resample_theta_train",
#                             sampling_mode="conor_train_gauss_source_10e10_resample_theta", 
#                             num_samples=1000000, low_lim_einst_angle_arcsec=0.5, 
#                             oversampling_factor=100
# #                            lens_grid=lens_grid
# )

# %%
#lens_grid=_grid_lens(3.0, 1000, device="cpu")
my_catalog = CatalogManager(catalog_name="test_catalog",
                            sampling_mode="conor_train_gauss_source_10e10_resample_theta", 
                            num_samples=100, low_lim_einst_angle_arcsec=0.5, 
                            oversampling_factor=100
#                            lens_grid=lens_grid
)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[3], line 2
#       1 #lens_grid=_grid_lens(3.0, 1000, device="cpu")
# ----> 2 my_catalog = CatalogManager(catalog_name="test_catalog",
#       3                             sampling_mode="conor_train_gauss_source_10e10_resample_theta",
#       4                             num_samples=100, low_lim_einst_angle_arcsec=0.5,
#       5                             oversampling_factor=100
#       6 #                            lens_grid=lens_grid
#       7 )
#
# File ~/Desktop/master_thesis_git_clean/master_thesis_code/src/catalog_manager/catalog_manager.py:53, in CatalogManager.__init__(self, catalog_name_input, catalog_name, catalog_description, sampling_mode, low_lim_einst_angle_arcsec, num_samples, lens_grid, oversampling_factor)
# ...

# %%
my_catalog = CatalogManager(catalog_name="conor_train_gauss_source_10e9_resample_theta_val_2",
                            sampling_mode="conor_train_gauss_source_10e9_resample_theta", 
                            num_samples=4000, low_lim_einst_angle_arcsec=0.5, 
                            oversampling_factor=100
#                            lens_grid=lens_grid
)

# %%
my_catalog = CatalogManager(catalog_name="conor_train_gauss_source_10e8_6_resample_theta_val_2",
                            sampling_mode="conor_train_gauss_source_10e8_6_resample_theta", 
                            num_samples=4000, low_lim_einst_angle_arcsec=0.5, 
                            oversampling_factor=100
#                            lens_grid=lens_grid
)

# %%
#lens_grid=_grid_lens(3.0, 1000, device="cpu")
my_catalog = CatalogManager(catalog_name="conor_train_gauss_source_10e9_resample_theta_train",
                            sampling_mode="conor_train_gauss_source_10e9_resample_theta", 
                            num_samples=1000000, low_lim_einst_angle_arcsec=0.5, 
                            oversampling_factor=100
#                            lens_grid=lens_grid
)

# %%
my_catalog=CatalogManager(catalog_name_input="conor_train_gauss_source_10e8_6_resample_theta_val_2")
# for i in range(100):
#     my_catalog.visualize_sample(index=i, lens_grid=lens_grid)

#my_catalog.visualize_sample(index=0, lens_grid=lens_grid)
my_catalog.visualize_statistics()

# %%
my_catalog = CatalogManager(catalog_name="conor_similar_cat_min_10e11_val_small",
                            sampling_mode="conor_similar_train_gauss_source_low_ellipticity_min_sub_10e11", 
                            num_samples=4000, low_lim_einst_angle_arcsec=0.1, 
                            lens_grid=lens_grid)



my_catalog = CatalogManager(catalog_name="conor_similar_cat_min_10e10_val_small",
                            sampling_mode="conor_similar_train_gauss_source_low_ellipticity_min_sub_10e10", 
                            num_samples=4000, low_lim_einst_angle_arcsec=0.1, 
                            lens_grid=lens_grid)

my_catalog = CatalogManager(catalog_name="conor_similar_cat_min_10e9_val_small",
                            sampling_mode="conor_similar_train_gauss_source_low_ellipticity_min_sub_10e9", 
                            num_samples=4000, low_lim_einst_angle_arcsec=0.1, 
                            lens_grid=lens_grid)

my_catalog = CatalogManager(catalog_name="conor_similar_cat_min_10e8_val_small",
                            sampling_mode="conor_similar_train_gauss_source_low_ellipticity_min_sub_10e8", 
                            num_samples=4000, low_lim_einst_angle_arcsec=0.1, 
                            lens_grid=lens_grid)

# %%
from catalog_manager import CatalogManager

my_catalog=CatalogManager("conor_train_gauss_source_10e11")
my_catalog.visualize_statistics()

# %%
from catalog_manager import CatalogManager
from shared_utils import _grid_lens
lens_grid=_grid_lens(6.0, 100, device="cpu")
my_catalog=CatalogManager(catalog_name_input="test4_pemd")
# for i in range(100):
#     my_catalog.visualize_sample(index=i, lens_grid=lens_grid)

my_catalog.visualize_sample(index=0, lens_grid=lens_grid)


# def visual_one_sample():
    
#     my_catalog.visualize_sample(index=0, lens_grid=lens_grid)
    
    
# %prun visual_one_sample()

# %%
from catalog_manager import CatalogManager
from shared_utils import _grid_lens
lens_grid=_grid_lens(6.0, 1000, device="cpu")
my_catalog=CatalogManager(catalog_name_input="conor_train_gauss_source_10e9_resample_theta_val")
for i in range(20):
    my_catalog.visualize_sample(index=i, lens_grid=lens_grid)

# %%
from catalog_manager import CatalogManager
from shared_utils import _grid_lens, _plot2D_on_grid


lens_grid=_grid_lens(3.0, 1000, device="cpu")
my_catalog = CatalogManager(catalog_name="SIS_10e11_sub_train_small", sampling_mode="SIS_10e11_sub", num_samples=100000, low_lim_einst_angle_arcsec=0.1, lens_grid=lens_grid)
my_catalog = CatalogManager(catalog_name="SIS_10e10_sub_train_small", sampling_mode="SIS_10e10_sub", num_samples=100000, low_lim_einst_angle_arcsec=0.1, lens_grid=lens_grid)
my_catalog = CatalogManager(catalog_name="SIS_10e9_sub_train_small", sampling_mode="SIS_10e9_sub", num_samples=100000, low_lim_einst_angle_arcsec=0.1, lens_grid=lens_grid)
my_catalog = CatalogManager(catalog_name="SIS_10e8_sub_train_small", sampling_mode="SIS_10e8_sub", num_samples=100000, low_lim_einst_angle_arcsec=0.1, lens_grid=lens_grid)


# my_catalog = CatalogManager(catalog_name="SIS_10e11_sub_val", sampling_mode="SIS_10e11_sub", num_samples=4000, low_lim_einst_angle_arcsec=0.1, lens_grid=lens_grid)
# my_catalog = CatalogManager(catalog_name="SIS_10e10_sub_val", sampling_mode="SIS_10e10_sub", num_samples=4000, low_lim_einst_angle_arcsec=0.1, lens_grid=lens_grid)
# my_catalog = CatalogManager(catalog_name="SIS_10e9_sub_val", sampling_mode="SIS_10e9_sub", num_samples=4000, low_lim_einst_angle_arcsec=0.1, lens_grid=lens_grid)
# my_catalog = CatalogManager(catalog_name="SIS_10e8_sub_val", sampling_mode="SIS_10e8_sub", num_samples=4000, low_lim_einst_angle_arcsec=0.1, lens_grid=lens_grid)
#my_catalog = CatalogManager(catalog_name_input="SIS_10e10_sub_train.json")

my_catalog.visualize_statistics()

# %%
from catalog_manager import CatalogManager
from shared_utils import _grid_lens
lens_grid=_grid_lens(6.0, 1000, device="cpu")
my_catalog=CatalogManager(catalog_name_input="SIS_10e11_sub_train")
for i in range(20):
    my_catalog.visualize_sample(index=i, lens_grid=lens_grid)

# %%
from catalog_manager import CatalogManager
from shared_utils import _grid_lens, _plot2D_on_grid


lens_grid=_grid_lens(3.0, 1000, device="cpu")
my_catalog = CatalogManager(catalog_name="SIS_10e8_sub_val_extended", sampling_mode="SIS_10e8_sub", num_samples=4000, low_lim_einst_angle_arcsec=0.1, lens_grid=lens_grid)
my_catalog.visualize_statistics()
