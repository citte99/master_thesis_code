# %%
from deep_learning import MODEL_REGISTRY, DATASET_REGISTRY, custom_dataloader

MODEL_REGISTRY.list_available()
# Out:
# ['ResNet18',
#  'ResNet50',
#  'VisionTransformer',
#  'VisionTransformer_Custom',
#  'EfficientNetB0']

# %%
DATASET_REGISTRY.list_available()
# Out:
# ['AlmaSinglePsfDataset', 'NoNoiseDataset', 'SingleTelescopeNoiseDataset']

# %%
catalog_name= "test_catalog"

dataset= DATASET_REGISTRY.get("NonNoiseDataset")
