# %%
from substructure_classifier import SubstructureClassifier
from substructure_classifier import Stage

# %%
my_classifier=SubstructureClassifier("classifier_trained_black_holes")

# %%
my_classifier.visualize_stages()
# Out:
# Loss plot saved to /home/francesco/Desktop/master_thesis_code/trained_classifiers/classifier_trained_black_holes/plots/6ac5898634a6130806329eb78799fd0d_loss_plot.png
# Loss plot saved to /home/francesco/Desktop/master_thesis_code/trained_classifiers/classifier_trained_black_holes/plots/cc56ec5ecdc0fa040a6049e9f0abaf68_loss_plot.png
# Loss plot saved to /home/francesco/Desktop/master_thesis_code/trained_classifiers/classifier_trained_black_holes/plots/dfeeadf2df66df8c0549ea1f10f9cb99_loss_plot.png
# Loss plot saved to /home/francesco/Desktop/master_thesis_code/trained_classifiers/classifier_trained_black_holes/plots/bcacf36c1f59c3003205dd3ea31bba50_loss_plot.png
# Loss plot saved to /home/francesco/Desktop/master_thesis_code/trained_classifiers/classifier_trained_black_holes/plots/b28ffec2bc2e895babdae0769d7a5ad3_loss_plot.png
# Loss plot saved to /home/francesco/Desktop/master_thesis_code/trained_classifiers/classifier_trained_black_holes/plots/9041ec4f948065d191db892e7c15c172_loss_plot.png
# Loss plot saved to /home/francesco/Desktop/master_thesis_code/trained_classifiers/classifier_trained_black_holes/plots/4400d6465c7d5349cb889c50ee0c3ce7_loss_plot.png
# Loss plot saved to /home/francesco/Desktop/master_thesis_code/trained_classifiers/classifier_trained_black_holes/plots/9e6eed1c901025096b1fb65cf958435d_loss_plot.png
# Loss plot saved to /home/francesco/Desktop/master_thesis_code/trained_classifiers/classifier_trained_black_holes/plots/8c2d93a09599c19eacbafff51b430e5f_loss_plot.png
# Loss plot saved to /home/francesco/Desktop/master_thesis_code/trained_classifiers/classifier_trained_black_holes/plots/850b3f05dbf40e25b9d84fe4bd94bd0c_loss_plot.png
# Loss plot saved to /home/francesco/Desktop/master_thesis_code/trained_classifiers/classifier_trained_black_holes/plots/befc786100845bd02a291f18bb6c7f61_loss_plot.png
