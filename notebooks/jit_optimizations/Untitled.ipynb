# %% [markdown]
# # Example

# %%
import torch
from torch.profiler import profile, record_function, ProfilerActivity

# 1. Setup as before
device = torch.device('cuda')
def make_grid(H, W, device):
    ys = torch.linspace(-1, 1, H, device=device)
    xs = torch.linspace(-1, 1, W, device=device)
    yy, xx = torch.meshgrid(ys, xs, indexing='ij')
    return torch.stack([xx, yy], dim=-1)
grid = make_grid(256, 256, device)

def render_batch(einstein_radii, src_centers, src_sigma):
    B = einstein_radii.shape[0]
    mesh = grid.unsqueeze(0).expand(B, -1, -1, -1)
    r = torch.norm(mesh, dim=-1, keepdim=True) + 1e-6
    direction = mesh / r
    theta_E = einstein_radii.view(B,1,1,1)
    alpha   = theta_E * direction
    beta    = mesh - alpha
    ctr     = src_centers.view(B,1,1,2)
    sig     = src_sigma.view(B,1,1,1)
    dx      = beta - ctr
    return torch.exp(-0.5 * torch.sum(dx*dx, dim=-1) / (sig**2))

B = 8
einstein_radii = torch.linspace(0.1, 0.5, B, device=device)
src_centers    = torch.zeros(B,2,device=device)
src_centers[:,0] = torch.linspace(-0.3, 0.3, B)
src_sigma      = torch.full((B,), 0.1, device=device)

traced_fn      = torch.jit.trace(render_batch, (einstein_radii, src_centers, src_sigma))

# 2. Warm up both
for _ in range(20):
    render_batch(einstein_radii, src_centers, src_sigma)
    traced_fn(einstein_radii, src_centers, src_sigma)
torch.cuda.synchronize()

# 3. Profile both versions in separate regions
activities = [ProfilerActivity.CPU, ProfilerActivity.CUDA]
with profile(activities=activities, record_shapes=True) as prof:
    # raw Python version
    with record_function("RAW_render_batch"):
        for _ in range(50):
            render_batch(einstein_radii, src_centers, src_sigma)
    torch.cuda.synchronize()

    # JIT‐traced version
    with record_function("JIT_render_batch"):
        for _ in range(50):
            traced_fn(einstein_radii, src_centers, src_sigma)
    torch.cuda.synchronize()

# 4. Export trace
prof.export_chrome_trace("trace_raw_vs_jit.json")
print("Trace saved to trace_raw_vs_jit.json")
# Out:
# Trace saved to trace_raw_vs_jit.json
# STAGE:2025-05-22 10:29:14 5966:5966 ActivityProfilerController.cpp:294] Completed Stage: Warm Up
# STAGE:2025-05-22 10:29:14 5966:5966 ActivityProfilerController.cpp:300] Completed Stage: Collection
# STAGE:2025-05-22 10:29:14 5966:5966 output_json.cpp:417] Completed Stage: Post Processing

# %% [markdown]
# # start by analyzing the most expensive functions for batch preparation

# %%
from deep_learning import NoNoiseDataset 
from deep_learning import custom_dataloader

# %%
# dataset=AlmaSinglePsfDataset(catalog_dict=catalog_dict,
#                              psf_name="devon_first_advice_psf_3_pix_16_arcsec",
#                              noise_std=0.0,
#                              broadcasting=False)
dataset=NoNoiseDataset(
        catalog_name="conor_similar_cat_val.json",
        grid_width_arcsec=8.0,
        grid_pixel_side=1000,
        broadcasting=True,
        final_transform=False
)
# Out:
# Using device: cuda
# Currently this dataloader is calculating the images in float32

# %%
dataloader=custom_dataloader(dataset=dataset, batch_size=300, shuffle=False)

# %%
iterator=iter(dataloader)

def warmup():
    for i in range (3):
        batch, _ = next(iterator)
    
def target_eval():
    for i in range (10):
        batch, _ = next(iterator)
        

# %prun target_eval()
# Out:
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#          624334 function calls (479754 primitive calls) in 11.464 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       120   10.062    0.084   10.062    0.084 {built-in method torch.tensor}
#        10    0.921    0.092    0.959    0.096 util.py:3(_hyp2f1_series)
#     86808    0.140    0.000    0.140    0.000 {built-in method torch.as_tensor}
# 119704/3000    0.071    0.000    0.276    0.000 util.py:4(recursive_to_tensor)
# 29926/3000    0.035    0.000    0.274    0.000 util.py:7(<dictcomp>)
#        60    0.034    0.001    0.034    0.001 {built-in method torch.sqrt}
#        10    0.033    0.003   11.459    1.146 no_noise_dataset.py:59(get_batch)
#       270    0.028    0.000    0.028    0.000 {built-in method torch.stack}
#      3000    0.024    0.000    0.024    0.000 {method 'long' of 'torch._C._TensorBase' objects}
# 302040/301120    0.024    0.000    0.025    0.000 {built-in method builtins.isinstance}
#        30    0.021    0.001    0.021    0.001 {built-in method torch.exp}
#        10    0.005    0.000   10.098    1.010 lens_model.py:73(process_configs)
#        10    0.004    0.000    0.986    0.099 pemd.py:61(deflection_angle)
#     29956    0.004    0.000    0.004    0.000 {method 'items' of 'dict' objects}
#        10    0.003    0.000    0.003    0.000 {method 'amax' of 'torch._C._TensorBase' objects}
#       340    0.003    0.000    0.003    0.000 {built-in method torch.rsub}
#        10    0.003    0.000   11.462    1.146 dataloaders.py:48(<lambda>)
#      3140    0.003    0.000    0.003    0.000 {method 'to' of 'torch._C._TensorBase' objects}
#        10    0.003    0.000    0.005    0.001 nfw.py:183(__init__)
#      3000    0.002    0.000    0.162    0.000 util.py:16(<listcomp>)
#       120    0.002    0.000    0.002    0.000 {method 'pow' of 'torch._C._TensorBase' objects}
#       920    0.002    0.000    0.004    0.000 module.py:1268(__setattr__)
#        10    0.001    0.000    0.994    0.099 lens_model.py:236(deflection_field)
#        30    0.001    0.000    0.022    0.001 lens_model.py:158(build_param_tensor)
#     20926    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#        10    0.001    0.000    0.001    0.000 {method 'clamp_min' of 'torch._C._TensorBase' objects}
#        10    0.001    0.000    0.001    0.000 lensing_system.py:57(<listcomp>)
#       370    0.001    0.000    0.001    0.000 {method 'view' of 'torch._C._TensorBase' objects}
#        10    0.001    0.000    0.005    0.000 nfw.py:268(deflection_angle)
#        10    0.001    0.000    0.004    0.000 gaussian_blob.py:73(forward)
#      6000    0.001    0.000    0.001    0.000 util.py:12(<genexpr>)
#        10    0.001    0.000    0.001    0.000 external_potential.py:43(deflection_angle)
#        10    0.001    0.000    0.277    0.028 lensing_system.py:28(<listcomp>)
#       920    0.001    0.000    0.001    0.000 parameter.py:8(__instancecheck__)
#        70    0.001    0.000    0.001    0.000 {method 'copy_' of 'torch._C._TensorBase' objects}
#        10    0.001    0.000    0.001    0.000 {method 'repeat' of 'torch._C._TensorBase' objects}
#        30    0.001    0.000    0.001    0.000 {built-in method torch.ones_like}
#        10    0.001    0.000    0.002    0.000 pemd.py:33(__init__)
#       180    0.001    0.000    0.001    0.000 {built-in method torch.empty}
#        10    0.001    0.000    0.001    0.000 lensing_system.py:58(<listcomp>)
#      3000    0.001    0.000    0.002    0.000 {built-in method builtins.all}
#        10    0.001    0.000   10.062    1.006 external_potential.py:10(__init__)
#        70    0.001    0.000    0.001    0.000 module.py:307(__init__)
#        10    0.001    0.000    0.001    0.000 {built-in method torch.zeros_like}
#        10    0.001    0.000    0.001    0.000 fetch.py:58(<listcomp>)
#      5730    0.001    0.000    0.001    0.000 {method 'get' of 'dict' objects}
#        10    0.001    0.000    0.001    0.000 samplers.py:14(__iter__)
#        60    0.000    0.000    0.000    0.000 {built-in method torch.mul}
#        10    0.000    0.000    0.002    0.000 gaussian_blob.py:9(__init__)
#        10    0.000    0.000    0.000    0.000 lensing_system.py:60(<listcomp>)
#        10    0.000    0.000    0.000    0.000 lensing_system.py:59(<listcomp>)
#        10    0.000    0.000    0.000    0.000 lensing_system.py:62(<listcomp>)
#        10    0.000    0.000    0.000    0.000 lensing_system.py:61(<listcomp>)
#       460    0.000    0.000    0.006    0.000 _tensor.py:33(wrapped)
#        10    0.000    0.000    0.000    0.000 units.py:17(_arcsec_to_rad)
#        30    0.000    0.000    0.000    0.000 {method 'index_add_' of 'torch._C._TensorBase' objects}
#        10    0.000    0.000   10.392    1.039 lensing_system.py:13(__init__)
#        10    0.000    0.000    0.000    0.000 lens_model.py:219(<listcomp>)
#        20    0.000    0.000    0.000    0.000 {built-in method torch.zeros}
#        40    0.000    0.000    0.000    0.000 {built-in method torch.div}
#        10    0.000    0.000    0.005    0.001 no_noise_dataset.py:41(unit_max)
#        20    0.000    0.000    0.000    0.000 {built-in method torch.where}
#        10    0.000    0.000    0.000    0.000 lens_model.py:215(<listcomp>)
#        10    0.000    0.000    0.000    0.000 lens_model.py:214(<listcomp>)
#        10    0.000    0.000    0.000    0.000 lens_model.py:205(<listcomp>)
#        10    0.000    0.000    0.000    0.000 lensing_system.py:31(<listcomp>)
#        30    0.000    0.000    0.000    0.000 socket.py:474(send)
#        20    0.000    0.000    0.000    0.000 {built-in method torch.clamp}
#        10    0.000    0.000    0.000    0.000 lens_model.py:206(<listcomp>)
#        10    0.000    0.000    0.000    0.000 lens_model.py:220(<listcomp>)
#        20    0.000    0.000    0.000    0.000 {built-in method torch.log}
#        10    0.000    0.000    0.000    0.000 {method 'any' of 'torch._C._TensorBase' objects}
#        10    0.000    0.000    0.000    0.000 lens_model.py:216(<listcomp>)
#        10    0.000    0.000   10.098    1.010 lens_model.py:11(__init__)
#        10    0.000    0.000    0.000    0.000 {method 'resolve_conj' of 'torch._C._TensorBase' objects}
#        10    0.000    0.000    0.000    0.000 lens_model.py:193(<listcomp>)
#        10    0.000    0.000    0.000    0.000 {built-in method torch.addcmul}
#        10    0.000    0.000    0.000    0.000 lens_model.py:217(<listcomp>)
#        10    0.000    0.000    0.000    0.000 gaussian_blob.py:65(_get_rotation_factor)
#       340    0.000    0.000    0.003    0.000 _tensor.py:831(__rsub__)
#        10    0.000    0.000    0.000    0.000 lens_model.py:196(<listcomp>)
#        10    0.000    0.000    0.000    0.000 lens_model.py:207(<listcomp>)
#      3000    0.000    0.000    0.000    0.000 dataloaders.py:39(__getitem__)
#        10    0.000    0.000    0.994    0.099 lens_model.py:265(forward)
#        70    0.000    0.000    0.000    0.000 {built-in method torch._C._log_api_usage_once}
#        50    0.000    0.000    0.000    0.000 {method 'expand' of 'torch._C._TensorBase' objects}
#        10    0.000    0.000    0.000    0.000 lens_model.py:218(<listcomp>)
#     30/10    0.000    0.000    0.998    0.100 module.py:1184(_call_impl)
#        10    0.000    0.000    0.000    0.000 lens_model.py:195(<listcomp>)
#        10    0.000    0.000    0.000    0.000 {built-in method torch.sub}
#        20    0.000    0.000    0.000    0.000 {method 'unsqueeze' of 'torch._C._TensorBase' objects}
#       920    0.000    0.000    0.000    0.000 {function _ParameterMeta.__instancecheck__ at 0x152aa81ebdc0}
#        10    0.000    0.000    0.000    0.000 {built-in method torch.maximum}
#        10    0.000    0.000    0.998    0.100 lensing_system.py:108(forward)
#        10    0.000    0.000    0.000    0.000 {built-in method torch.cos}
#        10    0.000    0.000   11.464    1.146 dataloader.py:623(__next__)
#        20    0.000    0.000    0.000    0.000 {built-in method torch.view_as_complex}
#        10    0.000    0.000    0.000    0.000 {built-in method torch.atanh}
#        10    0.000    0.000    0.000    0.000 lensing_system.py:32(<listcomp>)
#        10    0.000    0.000    0.000    0.000 {built-in method torch._ops.profiler._record_function_exit}
#        10    0.000    0.000    0.000    0.000 {built-in method torch.sin}
#        10    0.000    0.000    0.000    0.000 {built-in method torch.atan}
#        10    0.000    0.000    0.000    0.000 {built-in method torch._ops.profiler._record_function_enter}
#        10    0.000    0.000    0.000    0.000 lens_model.py:198(<listcomp>)
#        10    0.000    0.000    0.000    0.000 lens_model.py:194(<listcomp>)
#        10    0.000    0.000    0.000    0.000 lens_model.py:197(<listcomp>)
#        10    0.000    0.000    0.000    0.000 {built-in method torch.add}
#        10    0.000    0.000    0.001    0.000 nfw.py:238(_initialize_buffers)
#        20    0.000    0.000    0.000    0.000 {built-in method torch.view_as_real}
#       460    0.000    0.000    0.000    0.000 {built-in method torch._C._has_torch_function}
#        10    0.000    0.000    0.000    0.000 {built-in method torch.conj}
#        20    0.000    0.000    0.001    0.000 iostream.py:500(write)
#        30    0.000    0.000    0.000    0.000 iostream.py:206(schedule)
#        10    0.000    0.000    0.000    0.000 gaussian_blob.py:42(_ensure_buffers)
#        10    0.000    0.000    0.000    0.000 profiler.py:491(__exit__)
#        30    0.000    0.000    0.000    0.000 {built-in method torch._C._get_tracing_state}
#       600    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        10    0.000    0.000    0.001    0.000 {built-in method builtins.print}
#        10    0.000    0.000    0.000    0.000 {method 'squeeze' of 'torch._C._TensorBase' objects}
#        10    0.000    0.000   11.463    1.146 dataloader.py:669(_next_data)
#        10    0.000    0.000   11.463    1.146 fetch.py:53(fetch)
#        30    0.000    0.000    0.000    0.000 mass_component.py:5(__init__)
#        20    0.000    0.000    0.000    0.000 _ops.py:437(__call__)
#         1    0.000    0.000   11.464   11.464 3143374352.py:7(target_eval)
#        30    0.000    0.000    0.000    0.000 threading.py:1113(is_alive)
#        10    0.000    0.000    0.000    0.000 profiler.py:487(__enter__)
#        20    0.000    0.000    0.000    0.000 iostream.py:418(_is_master_process)
#         1    0.000    0.000   11.464   11.464 {built-in method builtins.exec}
#        10    0.000    0.000    0.001    0.000 lens_model.py:109(<dictcomp>)
#        20    0.000    0.000    0.000    0.000 module.py:1252(__getattr__)
#        90    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#        10    0.000    0.000    0.000    0.000 profiler.py:478(__init__)
#     20/10    0.000    0.000   11.464    1.146 {built-in method builtins.next}
#        30    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#        30    0.000    0.000    0.000    0.000 module.py:1269(remove_from)
#        30    0.000    0.000    0.000    0.000 threading.py:1059(_wait_for_tstate_lock)
#        30    0.000    0.000    0.000    0.000 iostream.py:96(_event_pipe)
#        10    0.000    0.000    0.000    0.000 container.py:263(__init__)
#        20    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#        20    0.000    0.000    0.000    0.000 iostream.py:437(_schedule_flush)
#        10    0.000    0.000    0.000    0.000 source_model.py:8(__init__)
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#        10    0.000    0.000    0.001    0.000 dataloader.py:617(_next_index)
#        30    0.000    0.000    0.000    0.000 threading.py:529(is_set)
#        30    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         1    0.000    0.000   11.464   11.464 <string>:1(<module>)
#        10    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
