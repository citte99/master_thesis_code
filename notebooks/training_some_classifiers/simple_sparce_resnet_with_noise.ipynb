# %%
module('load', 'pytorch/gpu-cuda-12.1/2.2.0')
# Out:
# Loading pytorch/gpu-cuda-12.1/2.2.0
#   Loading requirement: cuda/12.1 cudnn/8.9.2

# %%
#!pip install onnx onnxscript onnxruntime-gpu
import torch

torch.set_float32_matmul_precision('high')

# %%
#! python train_low_res_resnet.py

# %%
from substructure_classifier.substructure_classifier_development import SubstructureClassifier
import json
example_config=SubstructureClassifier.get_example_classifier_config()
print(json.dumps(example_config, indent=4))

example_config["classifier_name"]="sparce_resnet_high_res4"

example_config["active_val_cats_live"]=[]
#     ["conor_similar_cat_min_10e11_val_no_shear_small", "SingleTelescopeNoiseDataset", {
#         "grid_width_arcsec":10.0,
#         "grid_pixel_side":120,
#         "broadcasting":False,
#         "sky_level":0.01,
#         "kernel_size":5,
#         "kernel_sigma":1.0,
#         "gain":100.0,

#     }

#     ],
#      ["conor_similar_cat_min_10e11_val_no_shear_small", "SingleTelescopeNoiseDataset", {
#         "grid_width_arcsec":10.0,
#         "grid_pixel_side":120,
#         "broadcasting":False,
#         "sky_level":0.01,
#         "kernel_size":5,
#         "kernel_sigma":1.0,
#         "gain":100.0,

#     }

#     ]
# ]
example_config["NN_model"]="SparseResNet50"
example_config["NN_config"]={
        "num_classes":2,
#        "threshold":0.1
}


my_classifier = SubstructureClassifier("sparce_resnet_high_res4", config_dict=example_config)
# Out:
# cuda
# {
#     "classifier_name": "test_classifier2",
#     "NN_model": "ResNet50",
#     "NN_config": {},
#     "active_val_cats_live": [
#         [
#             "SIS_10e9_sub_test",
#             "NoNoiseDataset",
#             {
#                 "grid_width_arcsec": 6.0,
#                 "grid_pixel_side": 100
#             }
#         ],
#         [
#             "SIS_10e8_sub_test",
#             "NoNoiseDataset",
#             {
#                 "grid_width_arcsec": 6.0,
#                 "grid_pixel_side": 100
#             }
#         ]
#     ]
# }
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[4], line 41
#      34 example_config["NN_model"]="SparseResNet50"
#      35 example_config["NN_config"]={
#      36         "num_classes":2,
#      37 #        "threshold":0.1
#      38 }
# ---> 41 my_classifier = SubstructureClassifier("sparce_resnet_high_res4", config_dict=example_config)
#
# File /raven/u/fcitterio/master_thesis_code/src/substructure_classifier/substructure_classifier_development.py:63, in SubstructureClassifier.__init__(self, classifier_name, config_dict)
#      60 elif config_dict is not None:
#      61     # Check if the classifier directory already exists
#      62     if os.path.exists(self.classifier_path):
# ---> 63         raise FileExistsError(f"Classifier {classifier_name} already exists. Provide a different name or delete the existing classifier.")
#      64     self.config = config_dict
#      65     self.config["active_stage_id"] = None
#
# FileExistsError: Classifier sparce_resnet_high_res4 already exists. Provide a different name or delete the existing classifier.

# %%
# from substructure_classifier.substructure_classifier_development import SubstructureClassifier

# my_classifier = SubstructureClassifier("SimpleResnetWithNoise1")

# my_classifier._plot_concatenated_data()

# %%
import torch
print(torch._dynamo.list_backends())

# %%
from substructure_classifier.training_stage_development import Stage
from substructure_classifier.substructure_classifier_development import SubstructureClassifier


example_config=Stage.get_example_config(return_config=True)
my_classifier=SubstructureClassifier("sparce_resnet_high_res4")

# example_config["training_catalog"]="conor_similar_cat_min_10e11_train_no_shear_small_high_conc.json"
# example_config["validation_like_train_catalog"]="conor_similar_cat_min_10e11_val_no_shear_small_high_conc.json"
# example_config["dataset_class_str"]="SingleTelescopeNoiseDataset"
# example_config["dataset_config"]={
#         "grid_width_arcsec":8.0,
#         "grid_pixel_side":100,
#         "broadcasting":False,
#         "sky_level":0.05,
#         "kernel_size":5,
#         "kernel_sigma":1.0,
#         "gain":100.0,
#         "final_transform": True
# }

# example_config["samples_used_for_training"]=100000
# example_config["samples_used_for_validation"]=3000
# example_config["batch_size"]=256
# example_config["jump_batch_val"]=50
# example_config["learning_rate"]=0.001
# example_config["epochs"]=1
# my_stage=Stage(classifier_instance=my_classifier, config=example_config, device="cuda")

# my_stage.train(train_ready=True, early_stopping=True)

#example_config["training_catalog"]="conor_similar_cat_min_10e11_val_cornor_like_rigorous"
example_config["training_catalog"]="conor_train_gauss_source_10e11_resample_theta_train"

example_config["validation_like_train_catalog"]="conor_train_gauss_source_10e11_resample_theta_val"
example_config["dataset_class_str"]="SingleTelescopeNoiseDataset"
example_config["dataset_config"]={
            "grid_width_arcsec":8.0,
            "grid_pixel_side":200,
            "broadcasting":True,
            "sky_level":0.05,
            "kernel_size":5,
            "kernel_sigma":1.0,
            "gain":500.0,
            "final_transform": False
}

example_config["samples_used_for_training"]=1000000#1000000
example_config["samples_used_for_validation"]=3000
example_config["batch_size"]=512
example_config["jump_batch_val"]=100
example_config["learning_rate"]=0.00004
example_config["epochs"]=6
my_stage=Stage(classifier_instance=my_classifier, config=example_config, device="cuda")

# %prun my_stage.train(train_ready=True, early_stopping=False)
# Out:
# cuda
# doneStage1
# doneStage2
# doneStage3
# doneStage4
# doneStage5
# load_stage1
# load_stage2
# load_stage2.1
# load_stage2.2
# load_stage3
# load_stage4
# load_stage5
# load_stage6
# doneStage6
# doneStage7
# load_stage1
# load_stage2
# load_stage2.1
# load_stage2.2
# load_stage3
# load_stage4
# load_stage5
# load_stage6
# forcing only one entry per catalog in add activ val cat live, substructure classifier dev
# Catalog conor_train_gauss_source_10e11_resample_theta_train already exists in active validation catalogs.
# should have updated the classifier config file
# forcing only one entry per catalog in add activ val cat live, substructure classifier dev
# Catalog conor_train_gauss_source_10e11_resample_theta_val already exists in active validation catalogs.
# should have updated the classifier config file
# load_stage1
# load_stage2
# load_stage2.1
# load_stage2.2
# load_stage3
# load_stage4
# load_stage5
# load_stage6
# Implement the device compatibility check in _check_ready_to_train, util.py
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# 1000000
# Model initialized with kaiming_init
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# 3000
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# 3000
# authomatic learning rate, disregarding suggestion in the config
# authomatic learning rate, disregarding suggestion in the config
# ▶️  Running LR-Finder …
#
# 20
# 1954
#   0%|          | 0/20 [00:00<?, ?it/s]
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Learning rate search finished. See the graph with {finder_name}.plot()
# 📈  Suggested max_lr (lr_peak) ≈ 6.16e-04
# 📈  Suggested max_lr (lr_peak) ≈ 6.16e-04
# authomatic learning rate, disregarding suggestion in the config
# hardcoding lr_best
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: francescocitterio99 (francescocitterio99-max-planck-society) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.11
# Run data is saved locally in <code>/raven/u/fcitterio/master_thesis_code/notebooks/training_some_classifiers/wandb/run-20250616_181432-rarmcds4</code>
# Syncing run <strong><a href='https://wandb.ai/francescocitterio99-max-planck-society/sparce_resnet_high_res4/runs/rarmcds4' target="_blank">solar-frog-4</a></strong> to <a href='https://wandb.ai/francescocitterio99-max-planck-society/sparce_resnet_high_res4' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/francescocitterio99-max-planck-society/sparce_resnet_high_res4' target="_blank">https://wandb.ai/francescocitterio99-max-planck-society/sparce_resnet_high_res4</a>
#  View run at <a href='https://wandb.ai/francescocitterio99-max-planck-society/sparce_resnet_high_res4/runs/rarmcds4' target="_blank">https://wandb.ai/francescocitterio99-max-planck-society/sparce_resnet_high_res4/runs/rarmcds4</a>
# Tracked catalogs: ['conor_train_gauss_source_10e11_resample_theta_train', 'conor_train_gauss_source_10e11_resample_theta_val']
# Epoch 1/6:   0%|          | 0/1954 [00:00<?, ?batch/s]
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Training_loss= 0.8655074238777161, Validation_loss=0.6930676649411519
# New best validation loss: 0.693068
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Training_loss= 0.8096295069940019, Validation_loss=0.730652355670929
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# ...
#     self.run()
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 56
#      53 example_config["epochs"]=6
#      54 my_stage=Stage(classifier_instance=my_classifier, config=example_config, device="cuda")
# ---> 56 get_ipython().run_line_magic('prun', 'my_stage.train(train_ready=True, early_stopping=False)')
#
# File /mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2369, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2367     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2368 with self.builtin_trap:
# -> 2369     result = fn(*args, **kwargs)
#    2371 # The code below prevents the output from being displayed
#    2372 # when using magics with decodator @output_can_be_silenced
#    2373 # when the last Python token in the expression is a ';'.
#    2374 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/site-packages/IPython/core/magics/execution.py:297, in ExecutionMagics.prun(self, parameter_s, cell)
#     295     arg_str += '\n' + cell
#     296 arg_str = self.shell.transform_cell(arg_str)
# --> 297 return self._run_with_profiler(arg_str, opts, self.shell.user_ns)
#
# File /mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/site-packages/IPython/core/magics/execution.py:319, in ExecutionMagics._run_with_profiler(self, code, opts, namespace)
#     317 prof = profile.Profile()
#     318 try:
# --> 319     prof = prof.runctx(code, namespace, namespace)
#     320     sys_exit = ''
#     321 except SystemExit:
#
# File /mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/cProfile.py:100, in Profile.runctx(self, cmd, globals, locals)
#      98 self.enable()
#      99 try:
# --> 100     exec(cmd, globals, locals)
#     101 finally:
#     102     self.disable()
#
# File <string>:1
#
# File /raven/u/fcitterio/master_thesis_code/src/substructure_classifier/training_stage_development.py:895, in Stage.train(self, train_ready, early_stopping)
#     891     continue  # skip forward/backward/update on this batch
#     894 optimizer.zero_grad()
# --> 895 out = model(imgs)
#     896 loss = criterion(out, lbls)
#     898 # if not torch.isfinite(loss):
#     899 #     print("🚨 loss went bad:", loss)
#     900 #     import torch.autograd as ag; ag.detect_anomaly()
#
# File /mpcdf/soft/SLE_15/packages/skylake/pytorch/gpu-cuda-12.1/anaconda_3_2023.03-2023.03/2.2.0/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /mpcdf/soft/SLE_15/packages/skylake/pytorch/gpu-cuda-12.1/anaconda_3_2023.03-2023.03/2.2.0/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /mpcdf/soft/SLE_15/packages/skylake/pytorch/gpu-cuda-12.1/anaconda_3_2023.03-2023.03/2.2.0/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:489, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     487     dynamo_config_ctx.__enter__()
#     488 try:
# --> 489     return fn(*args, **kwargs)
#     490 finally:
#     491     set_eval_frame(prior)
#
# File /mpcdf/soft/SLE_15/packages/skylake/pytorch/gpu-cuda-12.1/anaconda_3_2023.03-2023.03/2.2.0/lib/python3.10/site-packages/torch/_dynamo/external_utils.py:17, in wrap_inline.<locals>.inner(*args, **kwargs)
#      15 @functools.wraps(fn)
#      16 def inner(*args, **kwargs):
# ---> 17     return fn(*args, **kwargs)
#
# File /mpcdf/soft/SLE_15/packages/skylake/pytorch/gpu-cuda-12.1/anaconda_3_2023.03-2023.03/2.2.0/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /mpcdf/soft/SLE_15/packages/skylake/pytorch/gpu-cuda-12.1/anaconda_3_2023.03-2023.03/2.2.0/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /mpcdf/soft/SLE_15/packages/skylake/pytorch/gpu-cuda-12.1/anaconda_3_2023.03-2023.03/2.2.0/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:489, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     487     dynamo_config_ctx.__enter__()
#     488 try:
# --> 489     return fn(*args, **kwargs)
#     490 finally:
#     491     set_eval_frame(prior)
#
# File /raven/u/fcitterio/master_thesis_code/src/deep_learning/NN_models/sparse_resnet50.py:365, in SparseResNet.forward(self, x)
#     362 x = dense_to_sparse(x)
#     364 # 2) initial conv + BN + ReLU
# --> 365 x = self.conv1(x)
#     366 feats = self.relu(self.bn1(x.features))
#     367 x = x.replace_feature(feats)
#
# File /mpcdf/soft/SLE_15/packages/skylake/pytorch/gpu-cuda-12.1/anaconda_3_2023.03-2023.03/2.2.0/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /mpcdf/soft/SLE_15/packages/skylake/pytorch/gpu-cuda-12.1/anaconda_3_2023.03-2023.03/2.2.0/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /raven/u/fcitterio/.local/lib/python3.10/site-packages/spconv/pytorch/conv.py:755, in SparseConvolution.forward(self, input, add_input)
#     752 def forward(self,
#     753             input: SparseConvTensor,
#     754             add_input: Optional[SparseConvTensor] = None):
# --> 755     return self._conv_forward(self.training,
#     756                               input,
#     757                               self.weight,
#     758                               self.bias,
#     759                               add_input,
#     760                               name=self.name,
#     761                               sparse_unique_name=self._sparse_unique_name,
#     762                               act_type=self.act_type,
#     763                               act_alpha=self.act_alpha,
#     764                               act_beta=self.act_beta)
#
# File /raven/u/fcitterio/.local/lib/python3.10/site-packages/spconv/pytorch/conv.py:284, in SparseConvolutionBase._conv_forward(self, training, input, weight, bias, add_input, channel_scale, output_scale, name, sparse_unique_name, act_type, act_alpha, act_beta)
#     282     t = time.time()
#     283 try:
# --> 284     outids, indice_pairs, indice_pair_num = ops.get_indice_pairs(
#     285         indices, batch_size, spatial_shape, algo,
#     286         self.kernel_size, self.stride, self.padding,
#     287         self.dilation, self.output_padding, self.subm,
#     288         self.transposed)
#     289 except Exception as e:
#     290     msg = "[Exception|native_pair]"
#
# File /raven/u/fcitterio/.local/lib/python3.10/site-packages/spconv/pytorch/ops.py:156, in get_indice_pairs(indices, batch_size, spatial_shape, algo, ksize, stride, padding, dilation, out_padding, subm, transpose, num_out_act_bound)
#     153 if indices.is_cuda:
#     154     stream = get_current_stream()
# --> 156 num_act_out = SpconvOps.get_indice_pairs(alloc,
#     157                                          torch_tensor_to_tv(indices),
#     158                                          batch_size, spatial_shape,
#     159                                          algo.value, ksize, stride,
#     160                                          padding, dilation,
#     161                                          out_padding, subm, transpose,
#     162                                          stream)
#     163 if subm:
#     164     out_inds = indices
#
# KeyboardInterrupt:
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
# KeyboardInterrupt
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Process ForkProcess-11:
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
# Process ForkProcess-12:
# Traceback (most recent call last):
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/multiprocessing/queues.py", line 103, in get
#     res = self._recv_bytes()
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
# Traceback (most recent call last):
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/mpcdf/soft/SLE_15/packages/x86_64/anaconda/3/2023.03/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()

# %%
# !python train_high_res_resnet.py

# %%
#! python3.10 -m pip uninstall triton
! python3.10 -m pip show triton

# %%
import torch
print(torch._dynamo.list_backends())
print(torch.cuda.memory_summary(device=0, abbreviated=True))

# %%
#### from substructure_classifier.training_stage_development import Stage
from substructure_classifier.substructure_classifier_development import SubstructureClassifier


example_config=Stage.get_example_config(return_config=True)
my_classifier=SubstructureClassifier("SimpleResnetWithNoise18")

# example_config["training_catalog"]="conor_similar_cat_min_10e11_train_no_shear_small_high_conc.json"
# example_config["validation_like_train_catalog"]="conor_similar_cat_min_10e11_val_no_shear_small_high_conc.json"
# example_config["dataset_class_str"]="SingleTelescopeNoiseDataset"
# example_config["dataset_config"]={
#         "grid_width_arcsec":8.0,
#         "grid_pixel_side":100,
#         "broadcasting":False,
#         "sky_level":0.05,
#         "kernel_size":5,
#         "kernel_sigma":1.0,
#         "gain":100.0,
#         "final_transform": True
# }

# example_config["samples_used_for_training"]=100000
# example_config["samples_used_for_validation"]=3000
# example_config["batch_size"]=256
# example_config["jump_batch_val"]=50
# example_config["learning_rate"]=0.001
# example_config["epochs"]=1
# my_stage=Stage(classifier_instance=my_classifier, config=example_config, device="cuda")

# my_stage.train(train_ready=True, early_stopping=True)

example_config["training_catalog"]="conor_similar_cat_min_10e11_train_no_shear_small_medium_conc.json"
example_config["validation_like_train_catalog"]="conor_similar_cat_min_10e11_val_no_shear_small_medium_conc.json"
example_config["dataset_class_str"]="SingleTelescopeNoiseDataset"
example_config["dataset_config"]={
        "grid_width_arcsec":6.0,
        "grid_pixel_side":100,
        "broadcasting":False,
        "sky_level":0.01,
        "kernel_size":5,
        "kernel_sigma":1.0,
        "gain":100.0,
        "final_transform": True
}

example_config["samples_used_for_training"]=100000
example_config["samples_used_for_validation"]=2000
example_config["batch_size"]=512
example_config["jump_batch_val"]=20
example_config["learning_rate"]=0.0001
example_config["epochs"]=4
my_stage=Stage(classifier_instance=my_classifier, config=example_config, device="cuda")

my_stage.train(train_ready=True, early_stopping=False)

# %%
from substructure_classifier.training_stage_development import Stage
from substructure_classifier.substructure_classifier_development import SubstructureClassifier


example_config=Stage.get_example_config(return_config=True)
my_classifier=SubstructureClassifier("SimpleResnetWithNoise20")

# example_config["training_catalog"]="conor_similar_cat_min_10e11_train_no_shear_small_high_conc.json"
# example_config["validation_like_train_catalog"]="conor_similar_cat_min_10e11_val_no_shear_small_high_conc.json"
# example_config["dataset_class_str"]="SingleTelescopeNoiseDataset"
# example_config["dataset_config"]={
#         "grid_width_arcsec":8.0,
#         "grid_pixel_side":100,
#         "broadcasting":False,
#         "sky_level":0.05,
#         "kernel_size":5,
#         "kernel_sigma":1.0,
#         "gain":100.0,
#         "final_transform": True
# }

# example_config["samples_used_for_training"]=100000
# example_config["samples_used_for_validation"]=3000
# example_config["batch_size"]=256
# example_config["jump_batch_val"]=50
# example_config["learning_rate"]=0.001
# example_config["epochs"]=1
# my_stage=Stage(classifier_instance=my_classifier, config=example_config, device="cuda")

# my_stage.train(train_ready=True, early_stopping=True)

example_config["training_catalog"]="conor_similar_cat_min_10e11_train_no_shear_small_medium_less_conc.json"
example_config["validation_like_train_catalog"]="conor_similar_cat_min_10e11_val_no_shear_small_medium_less_conc.json"
example_config["dataset_class_str"]="SingleTelescopeNoiseDataset"
example_config["dataset_config"]={
        "grid_width_arcsec":6.0,
        "grid_pixel_side":100,
        "broadcasting":False,
        "sky_level":0.01,
        "kernel_size":5,
        "kernel_sigma":1.0,
        "gain":100.0,
        "final_transform": True
}

example_config["samples_used_for_training"]=100000
example_config["samples_used_for_validation"]=2000
example_config["batch_size"]=1024
example_config["jump_batch_val"]=10
example_config["learning_rate"]=0.0001
example_config["epochs"]=3
my_stage=Stage(classifier_instance=my_classifier, config=example_config, device="cuda")

my_stage.train(train_ready=True, early_stopping=False)

# %%
from substructure_classifier.training_stage_development import Stage
from substructure_classifier.substructure_classifier_development import SubstructureClassifier


example_config=Stage.get_example_config(return_config=True)
my_classifier=SubstructureClassifier("SimpleResnetWithNoise20")

example_config["training_catalog"]="conor_similar_cat_min_10e10_train_cornor_like_rigorous_big"
example_config["validation_like_train_catalog"]="conor_similar_cat_min_10e10_val_cornor_like_rigorous"
example_config["dataset_class_str"]="SingleTelescopeNoiseDataset"
example_config["dataset_config"]={
        "grid_width_arcsec":6.0,
        "grid_pixel_side":100,
        "broadcasting":True,
        "sky_level":0.01,
        "kernel_size":5,
        "kernel_sigma":1.0,
        "gain":100.0,
        "final_transform": True
}


example_config["samples_used_for_training"]=1000000
example_config["samples_used_for_validation"]=2000
example_config["batch_size"]=1024
example_config["jump_batch_val"]=200
example_config["learning_rate"]=0.001
example_config["epochs"]=2
my_stage=Stage(classifier_instance=my_classifier, config=example_config, device="cuda")

my_stage.train(train_ready=True, early_stopping=False)

# %%
example_config=Stage.get_example_config(return_config=True)
my_classifier=SubstructureClassifier("SimpleResnetWithNoise1")

example_config["training_catalog"]="conor_similar_cat_min_10e10_train_small.json"
example_config["validation_like_train_catalog"]="conor_similar_cat_min_10e10_val.json"
example_config["dataset_class_str"]="SingleTelescopeNoiseDataset"
example_config["dataset_config"]={
        "grid_width_arcsec":8.0,
        "grid_pixel_side":100,
        "broadcasting":False,
        "sky_level":0.05,
        "kernel_size":5,
        "kernel_sigma":1.0,
        "gain":100.0,
        "final_transform": True
}


example_config["samples_used_for_training"]=100000
example_config["samples_used_for_validation"]=3000
example_config["batch_size"]=1024
example_config["jump_batch_val"]=50
example_config["learning_rate"]=0.00001
example_config["epochs"]=5
my_stage=Stage(classifier_instance=my_classifier, config=example_config, device="cuda")

my_stage.train(train_ready=True, early_stopping=True)

# %%
example_config=Stage.get_example_config(return_config=True)
my_classifier=SubstructureClassifier("SimpleResnetWithNoise1")

example_config["training_catalog"]="conor_similar_cat_min_10e10_train_small.json"
example_config["validation_like_train_catalog"]="conor_similar_cat_min_10e10_val.json"
example_config["dataset_class_str"]="SingleTelescopeNoiseDataset"
example_config["dataset_config"]={
        "grid_width_arcsec":8.0,
        "grid_pixel_side":100,
        "broadcasting":False,
        "sky_level":0.05,
        "kernel_size":5,
        "kernel_sigma":1.0,
        "gain":100.0,
        "final_transform": True
}


example_config["samples_used_for_training"]=100000
example_config["samples_used_for_validation"]=3000
example_config["batch_size"]=1024
example_config["jump_batch_val"]=50
example_config["learning_rate"]=0.000001
example_config["epochs"]=5
my_stage=Stage(classifier_instance=my_classifier, config=example_config, device="cuda")

my_stage.train(train_ready=True, early_stopping=True)

# %%
example_config=Stage.get_example_config(return_config=True)
my_classifier=SubstructureClassifier("SimpleResnetWithNoise1")

example_config["training_catalog"]="conor_similar_cat_min_10e9_train_small.json"
example_config["validation_like_train_catalog"]="conor_similar_cat_min_10e9_val.json"
example_config["dataset_class_str"]="SingleTelescopeNoiseDataset"
example_config["dataset_config"]={
        "grid_width_arcsec":8.0,
        "grid_pixel_side":100,
        "broadcasting":False,
        "sky_level":0.05,
        "kernel_size":5,
        "kernel_sigma":1.0,
        "gain":100.0,
        "final_transform": True
}


example_config["samples_used_for_training"]=100000
example_config["samples_used_for_validation"]=3000
example_config["batch_size"]=1024
example_config["jump_batch_val"]=50
example_config["learning_rate"]=0.0001
example_config["epochs"]=5
my_stage=Stage(classifier_instance=my_classifier, config=example_config, device="cuda")

my_stage.train(train_ready=True, early_stopping=True)

example_config=Stage.get_example_config(return_config=True)

my_classifier=SubstructureClassifier("SimpleResnetWithNoise1")

example_config["training_catalog"]="conor_similar_cat_min_10e9_train_small.json"
example_config["validation_like_train_catalog"]="conor_similar_cat_min_10e9_val.json"
example_config["dataset_class_str"]="SingleTelescopeNoiseDataset"
example_config["dataset_config"]={
        "grid_width_arcsec":8.0,
        "grid_pixel_side":100,
        "broadcasting":False,
        "sky_level":0.05,
        "kernel_size":5,
        "kernel_sigma":1.0,
        "gain":100.0,
        "final_transform": True
}


example_config["samples_used_for_training"]=100000
example_config["samples_used_for_validation"]=1000
example_config["batch_size"]=1024
example_config["jump_batch_val"]=50
example_config["learning_rate"]=0.00001
example_config["epochs"]=5
my_stage=Stage(classifier_instance=my_classifier, config=example_config, device="cuda")

my_stage.train(train_ready=True, early_stopping=True)

# %%
example_config=Stage.get_example_config(return_config=True)
my_classifier=SubstructureClassifier("SimpleResnetWithNoise1")

example_config["training_catalog"]="conor_similar_cat_train_small"
example_config["validation_like_train_catalog"]="conor_similar_cat_val"
example_config["dataset_class_str"]="SingleTelescopeNoiseDataset"
example_config["dataset_config"]={
        "grid_width_arcsec":8.0,
        "grid_pixel_side":100,
        "broadcasting":False,
        "sky_level":0.05,
        "kernel_size":5,
        "kernel_sigma":1.0,
        "gain":100.0,
        "final_transform": True
}


example_config["samples_used_for_training"]=100000
example_config["samples_used_for_validation"]=3000
example_config["batch_size"]=1024
example_config["jump_batch_val"]=50
example_config["learning_rate"]=0.0001
example_config["epochs"]=5
my_stage=Stage(classifier_instance=my_classifier, config=example_config, device="cuda")

my_stage.train(train_ready=True, early_stopping=True)

# %%
from substructure_classifier.training_stage_development import Stage
from substructure_classifier.substructure_classifier_development import SubstructureClassifier

example_config=Stage.get_example_config(return_config=True)

my_classifier=SubstructureClassifier("SimpleResnetWithNoise1")

example_config["training_catalog"]="conor_similar_cat_min_10e9_train_small.json"
example_config["validation_like_train_catalog"]="conor_similar_cat_min_10e9_val.json"
example_config["dataset_class_str"]="SingleTelescopeNoiseDataset"
example_config["dataset_config"]={
        "grid_width_arcsec":8.0,
        "grid_pixel_side":100,
        "broadcasting":False,
        "sky_level":0.01,
        "kernel_size":5,
        "kernel_sigma":0.8,
        "gain":1000.0,
        "final_transform": True,
        "broadcasting":True
}


example_config["samples_used_for_training"]=100000
example_config["samples_used_for_validation"]=2000
example_config["batch_size"]=1024
example_config["jump_batch_val"]=10
example_config["learning_rate"]=0.000001
example_config["epochs"]=5
my_stage=Stage(classifier_instance=my_classifier, config=example_config, device="cuda")

my_stage.train(train_ready=True, early_stopping=True)
