# %%
module('load', 'pytorch/gpu-cuda-12.1/2.2.0')
# Out:
# Loading pytorch/gpu-cuda-12.1/2.2.0
#   Loading requirement: cuda/12.1 cudnn/8.9.2

# %%
from substructure_classifier.substructure_classifier_development import SubstructureClassifier
from substructure_classifier.training_stage_development import Stage
# Out:
# cuda

# %%
loaded_classifier=SubstructureClassifier(classifier_name="ResnetNoiseHighRes")
#classifier_stage=Stage(classifier_instance=loaded_classifier , stage_id="f150c8927ca739fff70456a01caaedbdc3361c1872381fe1e9a811d2f3e2b83d")
classifier_stage=Stage(classifier_instance=loaded_classifier , stage_id="ed2f9fe85d0faeeb638f4ea5a627ad970c07a319f2b35a1333a24b6a5c396844")


# loaded_classifier=SubstructureClassifier(classifier_name="simple_vit5")
# classifier_stage=Stage(classifier_instance=loaded_classifier , stage_id="eb8e1c249ecda6e273fc8d233bec2894f3fcc4c1ba2c3c3b19e5466c1b8fe98c")




#loaded_classifier._plot_concatenated_data()

# %%
from catalog_manager import CatalogManager
from shared_utils import _grid_lens
lens_grid=_grid_lens(8.0, 1000, device="cpu")
my_catalog=CatalogManager(catalog_name_input="conor_train_gauss_source_10e10_resample_theta_val")

# for i in range (56, 76):
#     my_catalog.visualize_sample(index=i, lens_grid=lens_grid)
index=38 #34

my_catalog.visualize_sample(index=index, lens_grid=lens_grid)
system_dict=my_catalog.get_system_dict(idx=index)
# Out:
# /raven/u/fcitterio/master_thesis_code/src/lensing_system/lens_mass_components/pemd.py:58: UserWarning: q<0.8 in this hyp2f1 implementation may not converge
#   F = _hyp2f1_series(z, rs2, t, q)
# Found 3 clusters (expected caustics)
# /raven/u/fcitterio/master_thesis_code/src/lensing_system/lens_mass_components/pemd.py:58: UserWarning: q<0.8 in this hyp2f1 implementation may not converge
#   F = _hyp2f1_series(z, rs2, t, q)
# ┏━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Key          ┃ Value                                                                                ┃
# ┡━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ system_index │ 38                                                                                   │
# │ precomputed  │ ┏━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┓                                                   │
# │              │ ┃ Key     ┃ Value                ┃                                                   │
# │              │ ┡━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━┩                                                   │
# │              │ │ D_l     │ 1465.0316194300192   │                                                   │
# │              │ │ D_s     │ 1748.0985501650146   │                                                   │
# │              │ │ D_ls    │ 992.9417593188952    │                                                   │
# │              │ │ Theta_E │ 7.05362224120627e-06 │                                                   │
# │              │ └─────────┴──────────────────────┘                                                   │
# │ lens_model   │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓ │
# │              │ ┃ Key               ┃ Value                                                        ┃ │
# │              │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩ │
# │              │ │ num_substructures │ 1                                                            │ │
# │              │ │ mass_components   │ ┏━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓     │ │
# │              │ │                   │ ┃ Key             ┃ Value                              ┃     │ │
# │              │ │                   │ ┡━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩     │ │
# │              │ │                   │ │ type            │ PEMD                               │     │ │
# │              │ │                   │ │ is_substructure │ False                              │     │ │
# │              │ │                   │ │ params          │ ┏━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓ │     │ │
# │              │ │                   │ │                 │ ┃ Key      ┃ Value               ┃ │     │ │
# │              │ │                   │ │                 │ ┡━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩ │     │ │
# │              │ │                   │ │                 │ │ pos      │ 0.0                 │ │     │ │
# │              │ │                   │ │                 │ │          │ 0.0                 │ │     │ │
# │              │ │                   │ │                 │ │ redshift │ 0.6432579705678819  │ │     │ │
# │              │ │                   │ │                 │ │ vel_disp │ 298.01830334840514  │ │     │ │
# │              │ │                   │ │                 │ │ slope    │ 0.9386617410810218  │ │     │ │
# │              │ │                   │ │                 │ │ orient   │ 1.8794627901459493  │ │     │ │
# │              │ │                   │ │                 │ │ q        │ 0.43661981500905944 │ │     │ │
# │              │ │                   │ │                 │ └──────────┴─────────────────────┘ │     │ │
# │              │ │                   │ └─────────────────┴────────────────────────────────────┘     │ │
# │              │ │                   │ ┏━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓ │ │
# │              │ │                   │ ┃ Key             ┃ Value                                  ┃ │ │
# │              │ │                   │ ┡━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩ │ │
# │              │ │                   │ │ type            │ NFW                                    │ │ │
# │              │ │                   │ │ is_substructure │ True                                   │ │ │
# │              │ │                   │ │ params          │ ┏━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓ │ │ │
# │              │ │                   │ │                 │ ┃ Key       ┃ Value                  ┃ │ │ │
# │              │ │                   │ │                 │ ┡━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩ │ │ │
# │              │ │                   │ │                 │ │ pos       │ 6.80773512114527e-06   │ │ │ │
# │              │ │                   │ │                 │ │           │ 5.9340472182001685e-06 │ │ │ │
# │              │ │                   │ │                 │ │ mass_max  │ 16645659356.941282     │ │ │ │
# │              │ │                   │ │                 │ │ r_max_kpc │ 11.825676608958691     │ │ │ │
# │              │ │                   │ │                 │ │ redshift  │ 0.6432579705678819     │ │ │ │
# │              │ │                   │ │                 │ └───────────┴────────────────────────┘ │ │ │
# │              │ │                   │ └─────────────────┴────────────────────────────────────────┘ │ │
# │              │ └───────────────────┴──────────────────────────────────────────────────────────────┘ │
# │ source_model │ ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓                              │
# │              │ ┃ Key    ┃ Value                                      ┃                              │
# │              │ ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩                              │
# │              │ │ type   │ Gaussian_blob                              │                              │
# │              │ │ params │ ┏━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┓ │                              │
# │              │ │        │ ┃ Key          ┃ Value                   ┃ │                              │
# │              │ │        │ ┡━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━┩ │                              │
# │              │ │        │ │ I            │ 1.0                     │ │                              │
# │              │ │        │ │ position_rad │ -1.3447932312836325e-06 │ │                              │
# │              │ │        │ │              │ -7.024730730063366e-07  │ │                              │
# │              │ │        │ │ orient_rad   │ 0.0                     │ │                              │
# │              │ │        │ │ q            │ 0.8                     │ │                              │
# │              │ │        │ │ std_kpc      │ 0.8                     │ │                              │
# │              │ │        │ │ redshift     │ 2.187980184969189       │ │                              │
# │              │ │        │ └──────────────┴─────────────────────────┘ │                              │
# │              │ └────────┴────────────────────────────────────────────┘                              │
# └──────────────┴──────────────────────────────────────────────────────────────────────────────────────┘

# %%
from deep_learning import AlmaSinglePsfDataset, NoNoiseDataset, SingleTelescopeNoiseDataset
from deep_learning import custom_dataloader
import copy
import numpy as np
from shared_utils import units
import astropy.units as u


def get_r_max_from_M_max(M_max):
    M_max=M_max*u.M_sun
    A=0.344*u.kpc #kpc
    B=1.607
    const_1=(np.log(2.163+1.)+1/(2.163+1)-1)*4*np.pi
    #print(const_1)    
    from astropy.constants import G
    G = G.to(u.kpc * u.km**2/u.s**2 / u.M_sun)
    const_2=(10* u.km/u.s     /1.64/np.sqrt(G)   *(2.163/A)**(1/B)    )**2
    #print(const_2)
    r_s=((M_max/const_1/const_2).to(u.kpc**(1 + 2/B)))**(B/(B+2))
    r_max=2.163*r_s
    return r_max.to(u.kpc).value



system_dict_base=copy.deepcopy(system_dict)

mass_max_array=np.power(10, np.linspace(6, 11, 50))
system_dict_list=[]
for i, mass_max in enumerate(mass_max_array):
    system_dict=copy.deepcopy(system_dict_base)
    system_dict["system_index"]=i
    system_dict["lens_model"]["mass_components"][-1]["params"]["mass_max"]=mass_max
    system_dict["lens_model"]["mass_components"][-1]["params"]["r_max_kpc"]=get_r_max_from_M_max(mass_max)

    system_dict_list.append(system_dict)

catalog_dict={"SL_systems":system_dict_list}

import json
import torch
from collections import defaultdict
from pathlib import Path



def build_flat_catalog_sensitivity(one_system, output_path: str):
    """
    Read a JSON catalog of lensing systems and write out a "flat" binary file
    with pre-stacked tensors for:
     - precomputed quantities (one row per system)
     - each mass-component type (rows of [sys_idx, *params]
     - each source-model type (rows of [sys_idx, *params])
    Also emits a small `param_map` per component/source type to decode columns.

    Args:
        json_path: path to the input JSON file (dict with key "SL_systems")
        output_path: path where to save the flat catalog (.pt)
    """
    systems = catalog_dict.get("SL_systems", [])

    # Containers
    
    #For this one, differently form the following ones, there are not multiple tipes: we do not need default dict.
    #Also, here one row corresponds to one index, but for uniformity with following structures we write it like this.
    precomp_rows = {'sys_idxs': [], 'param_rows': []}
    
    labels={'sys_idxs': [], 'label_value': []}
    
    #default dict: mass_data["type"] does not exist beforehand, but this way it gets created authomatically when called
    mass_data = defaultdict(lambda: {'sys_idxs': [], 'param_rows': []})
    
    
    #This way we are able to deal eventually with multiple sources
    source_data = defaultdict(lambda: {'sys_idxs': [], 'param_rows': []})

    # Define param order maps
    
    
    precomp_map = ['D_l', 'D_s', 'D_ls', 'Theta_E']
    
#NOTE: These should be externalized.
    mass_param_map = {
        'SIS': ['pos_x','pos_y','redshift','vel_disp'],
        'NFW': ['pos_x', 'pos_y','mass_max','r_max_kpc','redshift'],
        'ExternalPotential': ['shear_x','shear_y','shear_strength','shear_angle_arcsec'],
        'PEMD': ['pos_x', 'pos_y', 'redshift', 'vel_disp', 'slope', 'orient', 'q']

    }
    
    
    
    source_param_map = {
        'Gaussian_blob': ['position_rad_x', 'position_rad_y', 'I' ,'orient_rad','q','std_kpc','redshift']
        # add other source types here
    }

    # Loop systems
    for sys in systems:
        i = sys['system_index']
        # precomputed
        pre = sys['precomputed']
        precomp_rows["sys_idxs"].append(i)
        
        row=[]
        for precomp_quant in precomp_map:
            row.append(pre[precomp_quant])
        precomp_rows["param_rows"].append(row)

        label=[0 if sys['lens_model']['num_substructures']==0 else 1]
        labels['sys_idxs'].append(i)
        labels['label_value'].append(label)

         # mass components
        for mc in sys['lens_model'].get('mass_components', []):
            mtype  = mc['type']
            params = mc['params']

            # 1) pull out all non-position params in order
            nonpos = []
            for key in mass_param_map[mtype]:
                if key not in ('pos_x', 'pos_y', 'shear_x', 'shear_y'):
                    nonpos.append(params[key][0] if isinstance(params[key], (list, tuple)) and len(params[key]) == 1 else params[key])



            # 2) build your final row as [pos_x, pos_y, *nonpos]
            # check if the key pos exists in the params dictionary
            if 'pos' in params:
                row = [params['pos'][0], params['pos'][1], *nonpos]

            elif 'shear_center' in params:
                row = [params['shear_center'][0], params['shear_center'][1], *nonpos]
            # store it
            mass_data[mtype]['sys_idxs'].append(i)
            mass_data[mtype]['param_rows'].append(row)

        # source models
        sm = sys['source_model']
        source_type = sm['type']
        params = sm['params']
       
            
        nonpos = []
        for key in source_param_map[source_type]:
            if key not in ('position_rad_x', 'position_rad_y'):
                nonpos.append(params[key][0] if isinstance(params[key], (list, tuple)) and len(params[key]) == 1 else params[key])

        # 2) build your final row as [pos_x, pos_y, *nonpos]
            
        row = [params['position_rad'][0], params['position_rad'][1], *nonpos]
            
        source_data[source_type]['sys_idxs'].append(i)
        source_data[source_type]['param_rows'].append(row)

    
    
    # Convert to tensors
    flat = {
        'precomputed': {},
        'mass_components': {},
        'source_models': {},
        'labels': {}
    }                   

    index_idxs=torch.tensor(labels['sys_idxs'], dtype=torch.long)
    index_vals=torch.tensor(labels['label_value'], dtype=torch.long)
    
    flat['labels'] = {
        'sys_idx': index_idxs,
        'label_values': index_vals
    }

    # Precomputed quantities — mirror the mass/source pattern
    pc_idxs = torch.tensor(precomp_rows['sys_idxs'], dtype=torch.long)
    pc_vals = torch.tensor(precomp_rows['param_rows'], dtype=torch.float32)
    


    
    flat['precomputed'] = {
        'sys_idx':   pc_idxs,
        'params':    pc_vals,
        'param_map': precomp_map
    }

    # Mass components
    for mtype, dat in mass_data.items():
        idxs = torch.tensor(dat['sys_idxs'], dtype=torch.long)
        rows = torch.tensor(dat['param_rows'], dtype=torch.float32)
        flat['mass_components'][mtype] = {
            'sys_idx':   idxs,
            'params':    rows,
            'param_map': mass_param_map[mtype]
        }

    # Source models
    for stype, dat in source_data.items():
        idxs = torch.tensor(dat['sys_idxs'], dtype=torch.long)
        rows = torch.tensor(dat['param_rows'], dtype=torch.float32)
        flat['source_models'][stype] = {
            'sys_idx':   idxs,
            'params':    rows,
            'param_map': source_param_map[stype]
        }

    # Save
    torch.save(flat, Path(output_path))
    print(f"Flat catalog written to {output_path}")


output_path="../catalogs/temp.pth"
build_flat_catalog_sensitivity(catalog_dict, output_path)


# print(mass_max_array)
# Out:
# Flat catalog written to ../catalogs/temp.pth

# %%
# import json

# print(json.dumps(catalog_dict, indent=4))

# %%
# dataset=AlmaSinglePsfDataset(catalog_dict=catalog_dict,
#                              psf_name="devon_first_advice_psf_3_pix_16_arcsec",
#                              noise_std=0.0,
#                              broadcasting=False)
dataset=SingleTelescopeNoiseDataset(
        catalog_name="temp",
        grid_width_arcsec=8.0,
        grid_pixel_side=200,
        broadcasting=True,
        sky_level=0.05,
        kernel_size=5,
        kernel_sigma= 1.0,
        gain=500.0
)
dataloader=custom_dataloader(dataset=dataset, batch_size=50, shuffle=False)
# Out:
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(50)

# %%
myiterator=iter(dataloader)
first_batch, _=next(myiterator)
# Out:
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it

# %%
# import torch
# import matplotlib.pyplot as plt

# fig, axes = plt.subplots(5, 5, figsize=(15, 10))  # Create a 3x4 grid for 10 images
# axes = axes.flatten()  # Flatten the axes array for easy iteration

# for i in range(25):
#     ax = axes[i]
#     ax.imshow(first_batch[i][0].to("cpu").squeeze().numpy(), cmap="viridis")
#     ax.set_title(f"Mass Max: {mass_max_array[i]:.2e}")
#     ax.axis("off")  # Turn off the axis for better visualization

# # Hide any unused subplots
# for j in range(12, len(axes)):
#     axes[j].axis("off")

# plt.tight_layout()
# plt.show()

# %%
import torch
from matplotlib import pyplot as plt

logits=classifier_stage.predict(first_batch)
pr= torch.softmax(logits, dim=1)
print(pr)
plt.plot(mass_max_array, pr[:, 1].detach().numpy())
#plt.axline((0.0, 0.5), slope=0.0)
plt.xscale("log")
plt.ylim(0.0, 1.01)
plt.show()
# Out:
# Loading paramters of the current stage, not the parent. This mode is intended for using an already trained stage for some evaluations
# tensor([[0.4613, 0.5387],
#         [0.4326, 0.5674],
#         [0.6073, 0.3927],
#         [0.5501, 0.4499],
#         [0.5602, 0.4398],
#         [0.5845, 0.4155],
#         [0.3018, 0.6982],
#         [0.6125, 0.3875],
#         [0.4997, 0.5003],
#         [0.5242, 0.4758],
#         [0.4980, 0.5020],
#         [0.6333, 0.3667],
#         [0.4540, 0.5460],
#         [0.6126, 0.3874],
#         [0.4402, 0.5598],
#         [0.4271, 0.5729],
#         [0.4327, 0.5673],
#         [0.5893, 0.4107],
#         [0.3057, 0.6943],
#         [0.4631, 0.5369],
#         [0.5816, 0.4184],
#         [0.2494, 0.7506],
#         [0.4564, 0.5436],
#         [0.3776, 0.6224],
#         [0.5054, 0.4946],
#         [0.5794, 0.4206],
#         [0.4773, 0.5227],
#         [0.4586, 0.5414],
#         [0.5999, 0.4001],
#         [0.4462, 0.5538],
#         [0.4985, 0.5015],
#         [0.4057, 0.5943],
#         [0.5393, 0.4607],
#         [0.3211, 0.6789],
#         [0.2536, 0.7464],
#         [0.2165, 0.7835],
#         [0.2406, 0.7594],
#         [0.5066, 0.4934],
#         [0.4533, 0.5467],
#         [0.1946, 0.8054],
#         [0.1241, 0.8759],
#         [0.1111, 0.8889],
#         [0.0929, 0.9071],
#         [0.0301, 0.9699],
#         [0.0503, 0.9497],
#         [0.0326, 0.9674],
#         [0.0217, 0.9783],
#         [0.0128, 0.9872],
#         [0.0207, 0.9793],
#         [0.0211, 0.9789]], grad_fn=<SoftmaxBackward0>)

# %%
pr_pos=pr[:, 1].detach().numpy()
pr_neg=pr[:, 0].detach().numpy()

R=np.log10(pr_pos/pr_neg)

# %%
import scipy
#now fit a curve
def relu_fit_curve(M_max, R_0, a, log_m_0):
    m_0=10**log_m_0
    M = np.asarray(M_max, dtype=float)        
    R = np.full_like(M, R_0, dtype=float)
    mask = M > m_0
    R[mask] = R_0 + a * np.log(M[mask] / m_0)

    # cast back to plain float if the input was scalar
    if np.isscalar(M_max):
        return float(R)
    return R



results, covariance=scipy.optimize.curve_fit(relu_fit_curve, mass_max_array, R, bounds=([-np.inf, -np.inf, 5], [+np.inf, +np.inf, +np.inf]))

plt.plot(mass_max_array, R)
plt.plot(mass_max_array, relu_fit_curve(mass_max_array, *results))
#plt.axline((0.0, 0.5), slope=0.0)
plt.xscale("log")
#plt.ylim(-1, 1.20)
plt.show()

print(f"R_0, a, log_m_0={results}")

print(mass_max_array)
print(relu_fit_curve(mass_max_array, *results))
# Out:
# R_0, a, log_m_0=[0.01965467 0.46292941 9.29590185]
# [1.00000000e+06 1.26485522e+06 1.59985872e+06 2.02358965e+06
#  2.55954792e+06 3.23745754e+06 4.09491506e+06 5.17947468e+06
#  6.55128557e+06 8.28642773e+06 1.04811313e+07 1.32571137e+07
#  1.67683294e+07 2.12095089e+07 2.68269580e+07 3.39322177e+07
#  4.29193426e+07 5.42867544e+07 6.86648845e+07 8.68511374e+07
#  1.09854114e+08 1.38949549e+08 1.75751062e+08 2.22299648e+08
#  2.81176870e+08 3.55648031e+08 4.49843267e+08 5.68986603e+08
#  7.19685673e+08 9.10298178e+08 1.15139540e+09 1.45634848e+09
#  1.84206997e+09 2.32995181e+09 2.94705170e+09 3.72759372e+09
#  4.71486636e+09 5.96362332e+09 7.54312006e+09 9.54095476e+09
#  1.20679264e+10 1.52641797e+10 1.93069773e+10 2.44205309e+10
#  3.08884360e+10 3.90693994e+10 4.94171336e+10 6.25055193e+10
#  7.90604321e+10 1.00000000e+11]
# [0.01965467 0.01965467 0.01965467 0.01965467 0.01965467 0.01965467
#  0.01965467 0.01965467 0.01965467 0.01965467 0.01965467 0.01965467
#  0.01965467 0.01965467 0.01965467 0.01965467 0.01965467 0.01965467
#  0.01965467 0.01965467 0.01965467 0.01965467 0.01965467 0.01965467
#  0.01965467 0.01965467 0.01965467 0.01965467 0.01965467 0.01965467
#  0.01965467 0.01965467 0.01965467 0.09581044 0.20457926 0.31334807
#  0.42211688 0.5308857  0.63965451 0.74842332 0.85719214 0.96596095
#  1.07472976 1.18349857 1.29226739 1.4010362  1.50980501 1.61857383
#  1.72734264 1.83611145]

# %%
from scipy.special import erf     # SciPy’s erf works on arrays
def R_from_s(s):

    s = np.asarray(s, dtype=float)
    t = erf(s / np.sqrt(2.0))          # t ∈ (−1, 1)
    return np.log((1.0 + t) / (1.0 - t))

# %%
R_lim=R_from_s(1.0)
print(R_lim)
# Out:
# 1.6682678659858132

# %%
def get_relu_intersect(fit_results, sigma_detect):

    R0, a, log_m0 = fit_results
    m0 = 10.0**log_m0                      # convert back to linear mass
    R_th = R_from_s(sigma_detect)          # log-odds threshold

    R_th = np.asarray(R_th, dtype=float)   # allows vector input

    # Case 1: threshold below (or equal) to plateau value  →  first hit at m0
    mask_plateau = R_th <= R0
    M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))

    # Return scalar if the input was scalar
    return float(M_star) if np.isscalar(sigma_detect) else M_star

# %%
M_intersect=get_relu_intersect(results, 1)
print(np.log10(M_intersect))
# Out:
# 10.842538534918422

# %% [markdown]
# # Lets try building a sensitivity map

# %%
system_dict_base=system_dict


dataset_sm=NoNoiseDataset(
        catalog_name="temp",
        grid_width_arcsec=8.0,
        grid_pixel_side=200,
        broadcasting=True,
#        sky_level=0.05,
#        kernel_size=5,
#        kernel_sigma= 1.0,
#        gain=500.0
)



num_masses=20


from shared_utils import _grid_lens

nx = ny = 40                        # grid resolution
grid_tensor = _grid_lens(6.0, nx, device="cpu")   # (ny, nx, 2) in *radians*

grid_np = grid_tensor.numpy()        # torch ➜ NumPy
pixels  = grid_np.reshape(-1, 2)     # (nx*ny, 2)  row-major order
# ------------------------------------------------------------------

# container that will hold the output map
M_detect_grid = np.full((ny, nx), np.nan, dtype=float)

from tqdm import tqdm
counter=0

for idx, pix_coord in enumerate(tqdm(pixels)):
    counter+=1
    mass_max_array=np.power(10, np.linspace(6, 11, num_masses))
    system_dict_list=[]
    for i, mass_max in enumerate(mass_max_array):
        system_dict=copy.deepcopy(system_dict_base)
        system_dict["system_index"]=i
        system_dict["lens_model"]["mass_components"][-1]["params"]["mass_max"]=mass_max
        system_dict["lens_model"]["mass_components"][-1]["params"]["r_max_kpc"]=get_r_max_from_M_max(mass_max)
        system_dict["lens_model"]["mass_components"][-1]["params"]["pos"]=pix_coord

        system_dict_list.append(system_dict)

    catalog_dict={"SL_systems":system_dict_list}
    
    output_path="../catalogs/temp.pth"
    build_flat_catalog_sensitivity(catalog_dict, output_path)
    
    dataset_sm=SingleTelescopeNoiseDataset(
        catalog_name="temp",
        grid_width_arcsec=8.0,
        grid_pixel_side=200,
        broadcasting=True,
        sky_level=0.05,
        kernel_size=5,
        kernel_sigma= 1.0,
        gain=500.0
    )

    dataloader = custom_dataloader(dataset=dataset_sm,
                               batch_size=num_masses,
                               shuffle=False)
    myiterator=iter(dataloader)
    first_batch, _=next(myiterator)
    
    
    logits=classifier_stage.predict(first_batch)
    pr= torch.softmax(logits, dim=1)
    pr_pos=pr[:, 1].detach().numpy()
    pr_neg=pr[:, 0].detach().numpy()

    R=np.log10(pr_pos/pr_neg)
    results, covariance=scipy.optimize.curve_fit(relu_fit_curve, mass_max_array, R, bounds=([-np.inf, -np.inf, 7], [+np.inf, +np.inf, +np.inf]))
    M_intersect=get_relu_intersect(results, 2)
    
    # ------------ write result into the 2-D output grid ----------
    row, col = divmod(idx, nx)        # because pixels was ravelled row-major
    M_detect_grid[row, col] = M_intersect
    
    
    plt.plot(mass_max_array, R)
    plt.plot(mass_max_array, relu_fit_curve(mass_max_array, *results))
    #plt.axline((0.0, 0.5), slope=0.0)
    plt.xscale("log")
    
    
    
# e.g. visualise it
from shared_utils import _plot2D_on_grid

M_clipped = torch.log10(torch.clamp(torch.tensor(M_detect_grid), 1e8, 1e11))

lo, hi = 1e5, 1e12                 # detection-mass limits

data = torch.tensor(M_detect_grid, dtype=torch.float32)   # copy if needed
mask = (data < lo) | (data > hi) | torch.isnan(data)      # out-of-range → True

# ---- Option A  : mark as "no data" with NaN  -----------------------
data[mask] = torch.nan            # NaN survives through log10 as NaN
M_for_plot = torch.log10(data)



_plot2D_on_grid(M_for_plot, grid_tensor)

plt.savefig("my_sensitivityMap.png")
# Out:
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
#   0%|          | 0/1600 [00:00<?, ?it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   0%|          | 2/1600 [00:00<05:24,  4.92it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
#   0%|          | 3/1600 [00:00<05:08,  5.18it/s]
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   0%|          | 5/1600 [00:00<04:47,  5.55it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# /tmp/ipykernel_26169/1666831520.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#   0%|          | 7/1600 [00:01<04:36,  5.77it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   1%|          | 9/1600 [00:01<04:28,  5.92it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   1%|          | 11/1600 [00:01<04:24,  6.00it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   1%|          | 13/1600 [00:02<04:24,  6.01it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   1%|          | 15/1600 [00:02<04:22,  6.04it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   1%|          | 17/1600 [00:02<04:20,  6.07it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   1%|          | 19/1600 [00:03<04:19,  6.09it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   1%|▏         | 21/1600 [00:03<04:19,  6.08it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   1%|▏         | 23/1600 [00:03<04:22,  6.02it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   2%|▏         | 25/1600 [00:04<04:22,  6.00it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   2%|▏         | 27/1600 [00:04<04:19,  6.07it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   2%|▏         | 29/1600 [00:04<04:17,  6.09it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   2%|▏         | 31/1600 [00:05<04:17,  6.09it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   2%|▏         | 33/1600 [00:05<04:20,  6.03it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   2%|▏         | 35/1600 [00:05<04:18,  6.05it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   2%|▏         | 37/1600 [00:06<04:16,  6.09it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   2%|▏         | 39/1600 [00:06<04:15,  6.10it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   3%|▎         | 41/1600 [00:06<04:16,  6.07it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   3%|▎         | 43/1600 [00:07<04:17,  6.05it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   3%|▎         | 45/1600 [00:07<04:15,  6.08it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   3%|▎         | 47/1600 [00:07<04:14,  6.10it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   3%|▎         | 49/1600 [00:08<04:14,  6.10it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   3%|▎         | 51/1600 [00:08<04:14,  6.09it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   3%|▎         | 53/1600 [00:08<04:16,  6.04it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   3%|▎         | 55/1600 [00:09<04:14,  6.07it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   4%|▎         | 57/1600 [00:09<04:13,  6.10it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   4%|▎         | 59/1600 [00:09<04:13,  6.08it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   4%|▍         | 61/1600 [00:10<04:11,  6.11it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   4%|▍         | 63/1600 [00:10<04:12,  6.10it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   4%|▍         | 65/1600 [00:10<04:13,  6.07it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   4%|▍         | 67/1600 [00:11<04:13,  6.05it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   4%|▍         | 69/1600 [00:11<04:11,  6.10it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   4%|▍         | 71/1600 [00:11<04:09,  6.12it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   5%|▍         | 73/1600 [00:12<04:09,  6.13it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   5%|▍         | 75/1600 [00:12<04:10,  6.09it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   5%|▍         | 77/1600 [00:12<04:08,  6.13it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   5%|▍         | 79/1600 [00:13<04:09,  6.10it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   5%|▌         | 81/1600 [00:13<04:11,  6.04it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   5%|▌         | 83/1600 [00:13<04:11,  6.03it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   5%|▌         | 85/1600 [00:14<04:13,  5.98it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   5%|▌         | 87/1600 [00:14<04:20,  5.81it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   6%|▌         | 89/1600 [00:14<04:15,  5.91it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   6%|▌         | 91/1600 [00:15<04:11,  6.00it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   6%|▌         | 93/1600 [00:15<04:08,  6.05it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   6%|▌         | 95/1600 [00:15<04:07,  6.09it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   6%|▌         | 97/1600 [00:16<04:08,  6.05it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   6%|▌         | 99/1600 [00:16<04:06,  6.09it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   6%|▋         | 101/1600 [00:16<04:06,  6.09it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   6%|▋         | 103/1600 [00:17<04:05,  6.10it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   7%|▋         | 105/1600 [00:17<04:04,  6.11it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   7%|▋         | 107/1600 [00:17<04:04,  6.10it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   7%|▋         | 109/1600 [00:18<04:03,  6.12it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   7%|▋         | 111/1600 [00:18<04:03,  6.12it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   7%|▋         | 113/1600 [00:18<04:02,  6.13it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   7%|▋         | 115/1600 [00:19<04:01,  6.15it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   7%|▋         | 117/1600 [00:19<04:02,  6.12it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#   7%|▋         | 119/1600 [00:19<04:02,  6.11it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# ...
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#  98%|█████████▊| 1562/1600 [04:17<00:06,  6.16it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#  98%|█████████▊| 1564/1600 [04:17<00:05,  6.19it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#  98%|█████████▊| 1566/1600 [04:18<00:05,  6.16it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#  98%|█████████▊| 1568/1600 [04:18<00:05,  6.06it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#  98%|█████████▊| 1570/1600 [04:18<00:04,  6.03it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#  98%|█████████▊| 1572/1600 [04:19<00:04,  5.96it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#  98%|█████████▊| 1574/1600 [04:19<00:04,  5.42it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#  98%|█████████▊| 1576/1600 [04:19<00:04,  5.83it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#  99%|█████████▊| 1578/1600 [04:20<00:03,  6.02it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#  99%|█████████▉| 1580/1600 [04:20<00:03,  5.99it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#  99%|█████████▉| 1582/1600 [04:20<00:02,  6.07it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#  99%|█████████▉| 1584/1600 [04:21<00:02,  6.17it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#  99%|█████████▉| 1586/1600 [04:21<00:02,  6.15it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#  99%|█████████▉| 1588/1600 [04:21<00:01,  6.20it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
#  99%|█████████▉| 1590/1600 [04:22<00:01,  6.26it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# 100%|█████████▉| 1592/1600 [04:22<00:01,  6.22it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# 100%|█████████▉| 1594/1600 [04:22<00:00,  6.25it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# 100%|█████████▉| 1596/1600 [04:23<00:00,  6.26it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# 100%|█████████▉| 1598/1600 [04:23<00:00,  6.25it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# 100%|██████████| 1600/1600 [04:23<00:00,  6.07it/s]
# Flat catalog written to ../catalogs/temp.pth
# Using device: cuda
# Using broadcasting mode
# Using device: cuda
# Currently this dataloader is calculating the images in float32
# tensor(20)
# Currently not cropping and rotating, set final_transform in the intialization to True to use it
# Currently not cropping and rotating, set final_transform in the intialization to True to use it

# %%
# e.g. visualise it
from shared_utils import _plot2D_on_grid

M_clipped = torch.log10(torch.clamp(torch.tensor(M_detect_grid), 1e8, 1e11))

lo, hi = 1e5, 1e12                 # detection-mass limits

data = torch.tensor(M_detect_grid, dtype=torch.float32)   # copy if needed
mask = (data < lo) | (data > hi) | torch.isnan(data)      # out-of-range → True

# ---- Option A  : mark as "no data" with NaN  -----------------------
data[mask] = torch.nan            # NaN survives through log10 as NaN
M_for_plot = torch.log10(data)



_plot2D_on_grid(M_for_plot, grid_tensor)

# %%
from catalog_manager import CatalogManager
from shared_utils import _grid_lens
lens_grid=_grid_lens(8.0, 1000, device="cpu")
my_catalog=CatalogManager(catalog_name_input="conor_train_gauss_source_10e10_resample_theta_val")

# for i in range (56, 76):
#     my_catalog.visualize_sample(index=i, lens_grid=lens_grid)
index=38 #34
# for i in range (56, 76):
#     my_catalog.visualize_sample(index=i, lens_grid=lens_grid)

my_catalog.visualize_sample(index=index, lens_grid=lens_grid)
system_dict=my_catalog.get_system_dict(idx=index)
# Out:
# /raven/u/fcitterio/master_thesis_code/src/lensing_system/lens_mass_components/pemd.py:58: UserWarning: q<0.8 in this hyp2f1 implementation may not converge
#   F = _hyp2f1_series(z, rs2, t, q)
# Found 3 clusters (expected caustics)
# /raven/u/fcitterio/master_thesis_code/src/lensing_system/lens_mass_components/pemd.py:58: UserWarning: q<0.8 in this hyp2f1 implementation may not converge
#   F = _hyp2f1_series(z, rs2, t, q)
# ┏━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Key          ┃ Value                                                                                ┃
# ┡━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ system_index │ 38                                                                                   │
# │ precomputed  │ ┏━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┓                                                   │
# │              │ ┃ Key     ┃ Value                ┃                                                   │
# │              │ ┡━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━┩                                                   │
# │              │ │ D_l     │ 1465.0316194300192   │                                                   │
# │              │ │ D_s     │ 1748.0985501650146   │                                                   │
# │              │ │ D_ls    │ 992.9417593188952    │                                                   │
# │              │ │ Theta_E │ 7.05362224120627e-06 │                                                   │
# │              │ └─────────┴──────────────────────┘                                                   │
# │ lens_model   │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓ │
# │              │ ┃ Key               ┃ Value                                                        ┃ │
# │              │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩ │
# │              │ │ num_substructures │ 1                                                            │ │
# │              │ │ mass_components   │ ┏━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓     │ │
# │              │ │                   │ ┃ Key             ┃ Value                              ┃     │ │
# │              │ │                   │ ┡━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩     │ │
# │              │ │                   │ │ type            │ PEMD                               │     │ │
# │              │ │                   │ │ is_substructure │ False                              │     │ │
# │              │ │                   │ │ params          │ ┏━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓ │     │ │
# │              │ │                   │ │                 │ ┃ Key      ┃ Value               ┃ │     │ │
# │              │ │                   │ │                 │ ┡━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩ │     │ │
# │              │ │                   │ │                 │ │ pos      │ 0.0                 │ │     │ │
# │              │ │                   │ │                 │ │          │ 0.0                 │ │     │ │
# │              │ │                   │ │                 │ │ redshift │ 0.6432579705678819  │ │     │ │
# │              │ │                   │ │                 │ │ vel_disp │ 298.01830334840514  │ │     │ │
# │              │ │                   │ │                 │ │ slope    │ 0.9386617410810218  │ │     │ │
# │              │ │                   │ │                 │ │ orient   │ 1.8794627901459493  │ │     │ │
# │              │ │                   │ │                 │ │ q        │ 0.43661981500905944 │ │     │ │
# │              │ │                   │ │                 │ └──────────┴─────────────────────┘ │     │ │
# │              │ │                   │ └─────────────────┴────────────────────────────────────┘     │ │
# │              │ │                   │ ┏━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓ │ │
# │              │ │                   │ ┃ Key             ┃ Value                                  ┃ │ │
# │              │ │                   │ ┡━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩ │ │
# │              │ │                   │ │ type            │ NFW                                    │ │ │
# │              │ │                   │ │ is_substructure │ True                                   │ │ │
# │              │ │                   │ │ params          │ ┏━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓ │ │ │
# │              │ │                   │ │                 │ ┃ Key       ┃ Value                  ┃ │ │ │
# │              │ │                   │ │                 │ ┡━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩ │ │ │
# │              │ │                   │ │                 │ │ pos       │ 6.80773512114527e-06   │ │ │ │
# │              │ │                   │ │                 │ │           │ 5.9340472182001685e-06 │ │ │ │
# │              │ │                   │ │                 │ │ mass_max  │ 16645659356.941282     │ │ │ │
# │              │ │                   │ │                 │ │ r_max_kpc │ 11.825676608958691     │ │ │ │
# │              │ │                   │ │                 │ │ redshift  │ 0.6432579705678819     │ │ │ │
# │              │ │                   │ │                 │ └───────────┴────────────────────────┘ │ │ │
# │              │ │                   │ └─────────────────┴────────────────────────────────────────┘ │ │
# │              │ └───────────────────┴──────────────────────────────────────────────────────────────┘ │
# │ source_model │ ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓                              │
# │              │ ┃ Key    ┃ Value                                      ┃                              │
# │              │ ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩                              │
# │              │ │ type   │ Gaussian_blob                              │                              │
# │              │ │ params │ ┏━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━┓ │                              │
# │              │ │        │ ┃ Key          ┃ Value                   ┃ │                              │
# │              │ │        │ ┡━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━┩ │                              │
# │              │ │        │ │ I            │ 1.0                     │ │                              │
# │              │ │        │ │ position_rad │ -1.3447932312836325e-06 │ │                              │
# │              │ │        │ │              │ -7.024730730063366e-07  │ │                              │
# │              │ │        │ │ orient_rad   │ 0.0                     │ │                              │
# │              │ │        │ │ q            │ 0.8                     │ │                              │
# │              │ │        │ │ std_kpc      │ 0.8                     │ │                              │
# │              │ │        │ │ redshift     │ 2.187980184969189       │ │                              │
# │              │ │        │ └──────────────┴─────────────────────────┘ │                              │
# │              │ └────────┴────────────────────────────────────────────┘                              │
# └──────────────┴──────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ######
