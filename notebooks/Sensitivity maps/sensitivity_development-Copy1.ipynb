# %%
from substructure_classifier.substructure_classifier_development import SubstructureClassifier
from substructure_classifier.training_stage_development import Stage

# %%
loaded_classifier=SubstructureClassifier(classifier_name="SimpleResnetWithNoise1")
#classifier_stage=Stage(classifier_instance=loaded_classifier , stage_id="f150c8927ca739fff70456a01caaedbdc3361c1872381fe1e9a811d2f3e2b83d")
classifier_stage=Stage(classifier_instance=loaded_classifier , stage_id="44eb74f20d03d1e17739b81a3b1fa38999a9a0a77224cd9fb0af5116eb08eaa3")


# loaded_classifier=SubstructureClassifier(classifier_name="simple_vit5")
# classifier_stage=Stage(classifier_instance=loaded_classifier , stage_id="eb8e1c249ecda6e273fc8d233bec2894f3fcc4c1ba2c3c3b19e5466c1b8fe98c")




#loaded_classifier._plot_concatenated_data()

# %%
from catalog_manager import CatalogManager
from shared_utils import _grid_lens
lens_grid=_grid_lens(6.0, 1000, device="cpu")
my_catalog=CatalogManager(catalog_name_input="conor_similar_cat_val")

# for i in range (56, 76):
#     my_catalog.visualize_sample(index=i, lens_grid=lens_grid)
index=126 #34

my_catalog.visualize_sample(index=index, lens_grid=lens_grid)
system_dict=my_catalog.get_system_dict(idx=index)
# Out:
# Found 1 clusters (expected caustics)
# ┏━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Key          ┃ Value                                                                                       ┃
# ┡━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ system_index │ 126                                                                                         │
# │ precomputed  │ ┏━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┓                                                         │
# │              │ ┃ Key     ┃ Value                 ┃                                                         │
# │              │ ┡━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━┩                                                         │
# │              │ │ D_l     │ 1722.8418753787687    │                                                         │
# │              │ │ D_s     │ 1223.4832674613926    │                                                         │
# │              │ │ D_ls    │ 370.8995636714161     │                                                         │
# │              │ │ Theta_E │ 3.983389322502142e-06 │                                                         │
# │              │ └─────────┴───────────────────────┘                                                         │
# │ lens_model   │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓ │
# │              │ ┃ Key               ┃ Value                                                               ┃ │
# │              │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩ │
# │              │ │ num_substructures │ 1                                                                   │ │
# │              │ │ mass_components   │ ┏━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓             │ │
# │              │ │                   │ ┃ Key             ┃ Value                             ┃             │ │
# │              │ │                   │ ┡━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩             │ │
# │              │ │                   │ │ type            │ PEMD                              │             │ │
# │              │ │                   │ │ is_substructure │ False                             │             │ │
# │              │ │                   │ │ params          │ ┏━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┓ │             │ │
# │              │ │                   │ │                 │ ┃ Key      ┃ Value              ┃ │             │ │
# │              │ │                   │ │                 │ ┡━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━┩ │             │ │
# │              │ │                   │ │                 │ │ pos      │ 0.0                │ │             │ │
# │              │ │                   │ │                 │ │          │ 0.0                │ │             │ │
# │              │ │                   │ │                 │ │ redshift │ 2.376631387356767  │ │             │ │
# │              │ │                   │ │                 │ │ vel_disp │ 306.5582472228264  │ │             │ │
# │              │ │                   │ │                 │ │ slope    │ 1.1278422018342777 │ │             │ │
# │              │ │                   │ │                 │ │ orient   │ 0.7782601332436179 │ │             │ │
# │              │ │                   │ │                 │ │ q        │ 0.8559984101096114 │ │             │ │
# │              │ │                   │ │                 │ └──────────┴────────────────────┘ │             │ │
# │              │ │                   │ └─────────────────┴───────────────────────────────────┘             │ │
# │              │ │                   │ ┏━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓ │ │
# │              │ │                   │ ┃ Key             ┃ Value                                         ┃ │ │
# │              │ │                   │ ┡━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩ │ │
# │              │ │                   │ │ type            │ ExternalPotential                             │ │ │
# │              │ │                   │ │ is_substructure │ False                                         │ │ │
# │              │ │                   │ │ params          │ ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┓ │ │ │
# │              │ │                   │ │                 │ ┃ Key                ┃ Value                ┃ │ │ │
# │              │ │                   │ │                 │ ┡━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━┩ │ │ │
# │              │ │                   │ │                 │ │ shear_center       │ 0.0                  │ │ │ │
# │              │ │                   │ │                 │ │                    │ 0.0                  │ │ │ │
# │              │ │                   │ │                 │ │ shear_strength     │ 0.030710363217127102 │ │ │ │
# │              │ │                   │ │                 │ │ shear_angle_arcsec │ 4.34562572334508     │ │ │ │
# │              │ │                   │ │                 │ └────────────────────┴──────────────────────┘ │ │ │
# │              │ │                   │ └─────────────────┴───────────────────────────────────────────────┘ │ │
# │              │ │                   │ ┏━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓        │ │
# │              │ │                   │ ┃ Key             ┃ Value                                  ┃        │ │
# │              │ │                   │ ┡━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩        │ │
# │              │ │                   │ │ type            │ NFW                                    │        │ │
# │              │ │                   │ │ is_substructure │ True                                   │        │ │
# │              │ │                   │ │ params          │ ┏━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓ │        │ │
# │              │ │                   │ │                 │ ┃ Key       ┃ Value                  ┃ │        │ │
# │              │ │                   │ │                 │ ┡━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩ │        │ │
# │              │ │                   │ │                 │ │ pos       │ 1.219041898553113e-05  │ │        │ │
# │              │ │                   │ │                 │ │           │ -2.786235253356002e-06 │ │        │ │
# │              │ │                   │ │                 │ │ mass_max  │ 2258379250.4510517     │ │        │ │
# │              │ │                   │ │                 │ │ r_max_kpc │ 13.383137604985993     │ │        │ │
# │              │ │                   │ │                 │ │ redshift  │ 2.376631387356767      │ │        │ │
# │              │ │                   │ │                 │ └───────────┴────────────────────────┘ │        │ │
# │              │ │                   │ └─────────────────┴────────────────────────────────────────┘        │ │
# │              │ └───────────────────┴─────────────────────────────────────────────────────────────────────┘ │
# │ source_model │ ┏━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓                                       │
# │              │ ┃ Key    ┃ Value                                    ┃                                       │
# │              │ ┡━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩                                       │
# │              │ │ type   │ Gaussian_blob                            │                                       │
# │              │ │ params │ ┏━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┓ │                                       │
# │              │ │        │ ┃ Key          ┃ Value                 ┃ │                                       │
# │              │ │        │ ┡━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━┩ │                                       │
# │              │ │        │ │ I            │ 1.0                   │ │                                       │
# │              │ │        │ │ position_rad │ 9.968623292639475e-07 │ │                                       │
# │              │ │        │ │              │ 6.022961650620856e-07 │ │                                       │
# │              │ │        │ │ orient_rad   │ 0.0                   │ │                                       │
# │              │ │        │ │ q            │ 0.8                   │ │                                       │
# │              │ │        │ │ std_kpc      │ 0.8                   │ │                                       │
# │              │ │        │ │ redshift     │ 5.82326195773687      │ │                                       │
# │              │ │        │ └──────────────┴───────────────────────┘ │                                       │
# │              │ └────────┴──────────────────────────────────────────┘                                       │
# └──────────────┴─────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
from deep_learning import AlmaSinglePsfDataset, NoNoiseDataset, SingleTelescopeNoiseDataset
from deep_learning import custom_dataloader
import copy
import numpy as np
from shared_utils import units

def get_r_max_from_M_max(M_max):
            const=2.16258
            A=0.344 #kpc
            B=1.607
            v_max=((1/const)*units.G/A*10**B*M_max)**(1/(B+2))#in km/s
            r_max=A*(v_max/10)**B #in kpc
            return r_max


system_dict_base=copy.deepcopy(system_dict)

mass_max_array=np.power(10, np.linspace(6, 11, 50))
system_dict_list=[]
for i, mass_max in enumerate(mass_max_array):
    system_dict=copy.deepcopy(system_dict_base)
    system_dict["system_index"]=i
    system_dict["lens_model"]["mass_components"][-1]["params"]["mass_max"]=mass_max
    system_dict["lens_model"]["mass_components"][-1]["params"]["r_max_kpc"]=get_r_max_from_M_max(mass_max)

    system_dict_list.append(system_dict)

catalog_dict={"SL_systems":system_dict_list}

print(mass_max_array)
# Out:
# [1.00000000e+06 1.26485522e+06 1.59985872e+06 2.02358965e+06
#  2.55954792e+06 3.23745754e+06 4.09491506e+06 5.17947468e+06
#  6.55128557e+06 8.28642773e+06 1.04811313e+07 1.32571137e+07
#  1.67683294e+07 2.12095089e+07 2.68269580e+07 3.39322177e+07
#  4.29193426e+07 5.42867544e+07 6.86648845e+07 8.68511374e+07
#  1.09854114e+08 1.38949549e+08 1.75751062e+08 2.22299648e+08
#  2.81176870e+08 3.55648031e+08 4.49843267e+08 5.68986603e+08
#  7.19685673e+08 9.10298178e+08 1.15139540e+09 1.45634848e+09
#  1.84206997e+09 2.32995181e+09 2.94705170e+09 3.72759372e+09
#  4.71486636e+09 5.96362332e+09 7.54312006e+09 9.54095476e+09
#  1.20679264e+10 1.52641797e+10 1.93069773e+10 2.44205309e+10
#  3.08884360e+10 3.90693994e+10 4.94171336e+10 6.25055193e+10
#  7.90604321e+10 1.00000000e+11]

# %%
# import json

# print(json.dumps(catalog_dict, indent=4))

# %%
# dataset=AlmaSinglePsfDataset(catalog_dict=catalog_dict,
#                              psf_name="devon_first_advice_psf_3_pix_16_arcsec",
#                              noise_std=0.0,
#                              broadcasting=False)
dataset=SingleTelescopeNoiseDataset(
        catalog_dict=catalog_dict,
        grid_width_arcsec=6.0,
        grid_pixel_side=100,
        broadcasting=True,
        sky_level=0.01,
        kernel_size=5,
        kernel_sigma= 1.0,
        gain=1000.0
)
dataloader=custom_dataloader(dataset=dataset, batch_size=50, shuffle=False)
# Out:
# Using device: cuda
# Currently this dataloader is calculating the images in float32

# %%
myiterator=iter(dataloader)
first_batch, _=next(myiterator)

# %%
# import torch
# import matplotlib.pyplot as plt

# fig, axes = plt.subplots(5, 5, figsize=(15, 10))  # Create a 3x4 grid for 10 images
# axes = axes.flatten()  # Flatten the axes array for easy iteration

# for i in range(25):
#     ax = axes[i]
#     ax.imshow(first_batch[i][0].to("cpu").squeeze().numpy(), cmap="viridis")
#     ax.set_title(f"Mass Max: {mass_max_array[i]:.2e}")
#     ax.axis("off")  # Turn off the axis for better visualization

# # Hide any unused subplots
# for j in range(12, len(axes)):
#     axes[j].axis("off")

# plt.tight_layout()
# plt.show()

# %%
import torch
from matplotlib import pyplot as plt

logits=classifier_stage.predict(first_batch)
pr= torch.softmax(logits, dim=1)
print(pr)
plt.plot(mass_max_array, pr[:, 1].detach().numpy())
#plt.axline((0.0, 0.5), slope=0.0)
plt.xscale("log")
plt.ylim(0.0, 1.01)
plt.show()
# Out:
# Loading paramters of the current stage, not the parent. This mode is intended for using an already trained stage for some evaluations
# tensor([[0.5349, 0.4651],
#         [0.5346, 0.4654],
#         [0.5488, 0.4512],
#         [0.5432, 0.4568],
#         [0.5384, 0.4616],
#         [0.5343, 0.4657],
#         [0.5326, 0.4674],
#         [0.5358, 0.4642],
#         [0.5226, 0.4774],
#         [0.5280, 0.4720],
#         [0.5465, 0.4535],
#         [0.5390, 0.4610],
#         [0.5130, 0.4870],
#         [0.5262, 0.4738],
#         [0.5196, 0.4804],
#         [0.5452, 0.4548],
#         [0.5374, 0.4626],
#         [0.5398, 0.4602],
#         [0.5407, 0.4593],
#         [0.5185, 0.4815],
#         [0.5342, 0.4658],
#         [0.5208, 0.4792],
#         [0.5438, 0.4562],
#         [0.5284, 0.4716],
#         [0.5177, 0.4823],
#         [0.5248, 0.4752],
#         [0.5259, 0.4741],
#         [0.5215, 0.4785],
#         [0.5376, 0.4624],
#         [0.5334, 0.4666],
#         [0.5364, 0.4636],
#         [0.5332, 0.4668],
#         [0.5266, 0.4734],
#         [0.5284, 0.4716],
#         [0.5296, 0.4704],
#         [0.5303, 0.4697],
#         [0.5269, 0.4731],
#         [0.5360, 0.4640],
#         [0.5171, 0.4829],
#         [0.5267, 0.4733],
#         [0.5232, 0.4768],
#         [0.5228, 0.4772],
#         [0.5272, 0.4728],
#         [0.5129, 0.4871],
#         [0.4996, 0.5004],
#         [0.5167, 0.4833],
#         [0.5144, 0.4856],
#         [0.4906, 0.5094],
#         [0.4963, 0.5037],
#         [0.5031, 0.4969]], grad_fn=<SoftmaxBackward0>)

# %%
pr_pos=pr[:, 1].detach().numpy()
pr_neg=pr[:, 0].detach().numpy()

R=np.log10(pr_pos/pr_neg)

# %%
import scipy
#now fit a curve
def relu_fit_curve(M_max, R_0, a, log_m_0):
    m_0=10**log_m_0
    M = np.asarray(M_max, dtype=float)        
    R = np.full_like(M, R_0, dtype=float)
    mask = M > m_0
    R[mask] = R_0 + a * np.log(M[mask] / m_0)

    # cast back to plain float if the input was scalar
    if np.isscalar(M_max):
        return float(R)
    return R



results, covariance=scipy.optimize.curve_fit(relu_fit_curve, mass_max_array, R, bounds=([-np.inf, -np.inf, 5], [+np.inf, +np.inf, +np.inf]))

plt.plot(mass_max_array, R)
plt.plot(mass_max_array, relu_fit_curve(mass_max_array, *results))
#plt.axline((0.0, 0.5), slope=0.0)
plt.xscale("log")
#plt.ylim(-1, 1.20)
plt.show()

print(f"R_0, a, log_m_0={results}")

print(mass_max_array)
print(relu_fit_curve(mass_max_array, *results))
# Out:
# R_0, a, log_m_0=[-6.36367516e-02  4.76155868e-03  7.17754639e+00]
# [1.00000000e+06 1.26485522e+06 1.59985872e+06 2.02358965e+06
#  2.55954792e+06 3.23745754e+06 4.09491506e+06 5.17947468e+06
#  6.55128557e+06 8.28642773e+06 1.04811313e+07 1.32571137e+07
#  1.67683294e+07 2.12095089e+07 2.68269580e+07 3.39322177e+07
#  4.29193426e+07 5.42867544e+07 6.86648845e+07 8.68511374e+07
#  1.09854114e+08 1.38949549e+08 1.75751062e+08 2.22299648e+08
#  2.81176870e+08 3.55648031e+08 4.49843267e+08 5.68986603e+08
#  7.19685673e+08 9.10298178e+08 1.15139540e+09 1.45634848e+09
#  1.84206997e+09 2.32995181e+09 2.94705170e+09 3.72759372e+09
#  4.71486636e+09 5.96362332e+09 7.54312006e+09 9.54095476e+09
#  1.20679264e+10 1.52641797e+10 1.93069773e+10 2.44205309e+10
#  3.08884360e+10 3.90693994e+10 4.94171336e+10 6.25055193e+10
#  7.90604321e+10 1.00000000e+11]
# [-0.06363675 -0.06363675 -0.06363675 -0.06363675 -0.06363675 -0.06363675
#  -0.06363675 -0.06363675 -0.06363675 -0.06363675 -0.06363675 -0.06363675
#  -0.06312207 -0.0620033  -0.06088454 -0.05976577 -0.05864701 -0.05752825
#  -0.05640948 -0.05529072 -0.05417195 -0.05305319 -0.05193442 -0.05081566
#  -0.04969689 -0.04857813 -0.04745936 -0.0463406  -0.04522183 -0.04410307
#  -0.0429843  -0.04186554 -0.04074678 -0.03962801 -0.03850925 -0.03739048
#  -0.03627172 -0.03515295 -0.03403419 -0.03291542 -0.03179666 -0.03067789
#  -0.02955913 -0.02844036 -0.0273216  -0.02620283 -0.02508407 -0.0239653
#  -0.02284654 -0.02172778]

# %%
from scipy.special import erf     # SciPy’s erf works on arrays
def R_from_s(s):

    s = np.asarray(s, dtype=float)
    t = erf(s / np.sqrt(2.0))          # t ∈ (−1, 1)
    return np.log((1.0 + t) / (1.0 - t))

# %%
R_lim=R_from_s(1.0)
print(R_lim)
# Out:
# 1.6682678659858134

# %%
def get_relu_intersect(fit_results, sigma_detect):

    R0, a, log_m0 = fit_results
    m0 = 10.0**log_m0                      # convert back to linear mass
    R_th = R_from_s(sigma_detect)          # log-odds threshold

    R_th = np.asarray(R_th, dtype=float)   # allows vector input

    # Case 1: threshold below (or equal) to plateau value  →  first hit at m0
    mask_plateau = R_th <= R0
    M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))

    # Return scalar if the input was scalar
    return float(M_star) if np.isscalar(sigma_detect) else M_star

# %%
M_intersect=get_relu_intersect(results, 1)
print(np.log10(M_intersect))
# Out:
# 165.1419165815685

# %% [markdown]
# # Lets try building a sensitivity map

# %%
system_dict_base=system_dict


dataset_sm=SingleTelescopeNoiseDataset(
        catalog_dict=catalog_dict,
        grid_width_arcsec=6.0,
        grid_pixel_side=100,
        broadcasting=True,
        sky_level=0.01,
        kernel_size=5,
        kernel_sigma= 1.0,
        gain=1000.0
)



num_masses=20


from shared_utils import _grid_lens

nx = ny = 40                        # grid resolution
grid_tensor = _grid_lens(4.0, nx, device="cpu")   # (ny, nx, 2) in *radians*

grid_np = grid_tensor.numpy()        # torch ➜ NumPy
pixels  = grid_np.reshape(-1, 2)     # (nx*ny, 2)  row-major order
# ------------------------------------------------------------------

# container that will hold the output map
M_detect_grid = np.full((ny, nx), np.nan, dtype=float)

from tqdm import tqdm


for idx, pix_coord in enumerate(tqdm(pixels)):
    mass_max_array=np.power(10, np.linspace(6, 11, num_masses))
    system_dict_list=[]
    for i, mass_max in enumerate(mass_max_array):
        system_dict=copy.deepcopy(system_dict_base)
        system_dict["system_index"]=i
        system_dict["lens_model"]["mass_components"][-1]["params"]["mass_max"]=mass_max
        system_dict["lens_model"]["mass_components"][-1]["params"]["r_max_kpc"]=get_r_max_from_M_max(mass_max)
        system_dict["lens_model"]["mass_components"][-1]["params"]["pos"]=pix_coord

        system_dict_list.append(system_dict)

    catalog_dict={"SL_systems":system_dict_list}
    
    dataset_sm.update_catalog_dict(catalog_dict)
    
    dataloader = custom_dataloader(dataset=dataset_sm,
                               batch_size=num_masses,
                               shuffle=False)
    myiterator=iter(dataloader)
    first_batch, _=next(myiterator)
    
    
    logits=classifier_stage.predict(first_batch)
    pr= torch.softmax(logits, dim=1)
    pr_pos=pr[:, 1].detach().numpy()
    pr_neg=pr[:, 0].detach().numpy()

    R=np.log10(pr_pos/pr_neg)
    results, covariance=scipy.optimize.curve_fit(relu_fit_curve, mass_max_array, R, bounds=([-np.inf, -np.inf, 7], [+np.inf, +np.inf, +np.inf]))
    M_intersect=get_relu_intersect(results, 1)
    
    # ------------ write result into the 2-D output grid ----------
    row, col = divmod(idx, nx)        # because pixels was ravelled row-major
    M_detect_grid[row, col] = M_intersect
    
    
    plt.plot(mass_max_array, R)
    plt.plot(mass_max_array, relu_fit_curve(mass_max_array, *results))
    #plt.axline((0.0, 0.5), slope=0.0)
    plt.xscale("log")
# Out:
# Using device: cuda
# Currently this dataloader is calculating the images in float32
#   1%|          | 17/1600 [00:01<02:35, 10.21it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#   1%|▏         | 23/1600 [00:02<02:31, 10.40it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#   4%|▎         | 57/1600 [00:05<02:26, 10.55it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#   4%|▎         | 59/1600 [00:05<02:27, 10.45it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#   6%|▌         | 95/1600 [00:09<02:22, 10.59it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#   9%|▊         | 137/1600 [00:13<02:18, 10.59it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  11%|█         | 179/1600 [00:17<02:14, 10.57it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  20%|█▉        | 319/1600 [00:30<02:02, 10.47it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in double_scalars
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  32%|███▏      | 519/1600 [00:49<01:43, 10.46it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  35%|███▌      | 561/1600 [00:53<01:40, 10.35it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  36%|███▌      | 575/1600 [00:55<01:39, 10.31it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  38%|███▊      | 603/1600 [00:57<01:36, 10.33it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  40%|████      | 641/1600 [01:01<01:32, 10.33it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  41%|████      | 655/1600 [01:02<01:31, 10.36it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  43%|████▎     | 681/1600 [01:05<01:28, 10.43it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  43%|████▎     | 689/1600 [01:06<01:28, 10.29it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
# /tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  43%|████▎     | 695/1600 [01:06<01:28, 10.22it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  45%|████▌     | 727/1600 [01:09<01:25, 10.18it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  50%|█████     | 801/1600 [01:17<01:17, 10.34it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  53%|█████▎    | 841/1600 [01:21<01:13, 10.36it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  53%|█████▎    | 847/1600 [01:21<01:14, 10.05it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  55%|█████▍    | 879/1600 [01:24<01:10, 10.30it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  55%|█████▌    | 887/1600 [01:25<01:10, 10.08it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  56%|█████▌    | 889/1600 [01:25<01:10, 10.04it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  58%|█████▊    | 925/1600 [01:29<01:04, 10.40it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  58%|█████▊    | 929/1600 [01:29<01:06, 10.16it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  60%|██████    | 967/1600 [01:33<01:02, 10.18it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  62%|██████▏   | 999/1600 [01:36<00:58, 10.22it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  63%|██████▎   | 1003/1600 [01:37<00:58, 10.13it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  65%|██████▌   | 1042/1600 [01:41<00:54, 10.16it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  65%|██████▌   | 1044/1600 [01:41<00:54, 10.12it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  66%|██████▌   | 1050/1600 [01:41<00:54, 10.02it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  68%|██████▊   | 1082/1600 [01:44<00:50, 10.30it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  68%|██████▊   | 1084/1600 [01:45<00:50, 10.15it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
# /tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  68%|██████▊   | 1090/1600 [01:45<00:50, 10.16it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  70%|███████   | 1120/1600 [01:48<00:47, 10.21it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  70%|███████   | 1122/1600 [01:48<00:47, 10.07it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  70%|███████   | 1126/1600 [01:49<00:46, 10.12it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
# /tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  70%|███████   | 1128/1600 [01:49<00:46, 10.14it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  75%|███████▌  | 1200/1600 [01:56<00:38, 10.32it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
# /tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  78%|███████▊  | 1240/1600 [02:00<00:35, 10.24it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
# /tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  78%|███████▊  | 1244/1600 [02:00<00:35, 10.05it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  78%|███████▊  | 1248/1600 [02:01<00:34, 10.07it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  78%|███████▊  | 1250/1600 [02:01<00:34, 10.01it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  78%|███████▊  | 1252/1600 [02:01<00:34, 10.10it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  80%|███████▉  | 1279/1600 [02:04<00:31, 10.06it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  80%|████████  | 1285/1600 [02:05<00:31, 10.01it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
# /tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  83%|████████▎ | 1321/1600 [02:08<00:27, 10.24it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  83%|████████▎ | 1323/1600 [02:08<00:27, 10.16it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  85%|████████▍ | 1359/1600 [02:12<00:23, 10.32it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  85%|████████▌ | 1361/1600 [02:12<00:23, 10.16it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in double_scalars
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  85%|████████▌ | 1363/1600 [02:12<00:23, 10.16it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  85%|████████▌ | 1367/1600 [02:13<00:23, 10.06it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  88%|████████▊ | 1400/1600 [02:16<00:19, 10.08it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
# /tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  88%|████████▊ | 1402/1600 [02:16<00:19, 10.04it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  90%|█████████ | 1441/1600 [02:20<00:15, 10.25it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
# /tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  90%|█████████ | 1445/1600 [02:20<00:15, 10.25it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  91%|█████████ | 1449/1600 [02:21<00:14, 10.25it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  93%|█████████▎| 1483/1600 [02:24<00:11, 10.27it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
# /tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  93%|█████████▎| 1489/1600 [02:25<00:10, 10.29it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  95%|█████████▌| 1527/1600 [02:28<00:07, 10.10it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in double_scalars
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
#  97%|█████████▋| 1559/1600 [02:32<00:04, 10.18it/s]/tmp/ipykernel_31301/2173472844.py:11: RuntimeWarning: overflow encountered in exp
#   M_star = np.where(mask_plateau, m0, m0 * np.exp((R_th - R0) / a))
# 100%|██████████| 1600/1600 [02:36<00:00, 10.23it/s]

# %%
# e.g. visualise it
from shared_utils import _plot2D_on_grid

M_clipped = torch.log10(torch.clamp(torch.tensor(M_detect_grid), 1e8, 1e11))

lo, hi = 1e5, 1e12                 # detection-mass limits

data = torch.tensor(M_detect_grid, dtype=torch.float32)   # copy if needed
mask = (data < lo) | (data > hi) | torch.isnan(data)      # out-of-range → True

# ---- Option A  : mark as "no data" with NaN  -----------------------
data[mask] = torch.nan            # NaN survives through log10 as NaN
M_for_plot = torch.log10(data)



_plot2D_on_grid(M_for_plot, grid_tensor)

# %%
from catalog_manager import CatalogManager
from shared_utils import _grid_lens
lens_grid=_grid_lens(4.0, 1000, device="cpu")
my_catalog=CatalogManager(catalog_name_input="conor_similar_cat_val")

# for i in range (56, 76):
#     my_catalog.visualize_sample(index=i, lens_grid=lens_grid)
index=115 #34

my_catalog.visualize_sample(index=index, lens_grid=lens_grid)
system_dict=my_catalog.get_system_dict(idx=index)
